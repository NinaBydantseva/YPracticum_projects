# %% [markdown]
# #  Прогнозирование заказов такси

# %% [markdown]
# Компания «Чётенькое такси» собрала исторические данные о заказах такси в аэропортах. Чтобы привлекать больше водителей в период пиковой нагрузки, нужно спрогнозировать количество заказов такси на следующий час. Постройте модель для такого предсказания.
#
# Значение метрики *RMSE* на тестовой выборке должно быть не больше 48.
#
# Вам нужно:
#
# 1. Загрузить данные и выполнить их ресемплирование по одному часу.
# 2. Проанализировать данные.
# 3. Обучить разные модели с различными гиперпараметрами. Сделать тестовую выборку размером 10% от исходных данных.
# 4. Проверить данные на тестовой выборке и сделать выводы.
#
#
# Данные лежат в файле `taxi.csv`. Количество заказов находится в столбце `num_orders` (от англ. *number of orders*, «число заказов»).

# %% [markdown]
# ## Подготовка

# %%
# импортируем все нужные библиотеки
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from catboost import CatBoostRegressor
from lightgbm import LGBMRegressor

from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.stattools import adfuller
from statsmodels.graphics import tsaplots

from sklearn.model_selection import (
    train_test_split,
    TimeSeriesSplit,
    cross_val_score,
    GridSearchCV
)
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor

from sklearn.metrics import mean_squared_error

# зададим параметры окна вывода графиков
plt.rcParams["figure.figsize"] = (15,7)

# %%
# считываем исходные данные из файла csv, записываем дату в индекс
try:
    df_taxi = pd.read_csv('/datasets/taxi.csv', sep=',', index_col=[0], parse_dates=[0])
except:
    df_taxi = pd.read_csv('c:/users/bny_7/datasets/taxi.csv', sep=',', index_col=[0], parse_dates=[0])

# %%
# отсортируем данные по индексу (дате) и отобразим содержимое набора данных
df_taxi.sort_index(inplace=True)
display(df_taxi.head())
# Out:
#                      num_orders
# datetime
# 2018-03-01 00:00:00           9
# 2018-03-01 00:10:00          14
# 2018-03-01 00:20:00          28
# 2018-03-01 00:30:00          20
# 2018-03-01 00:40:00          32

# %% [markdown]
# Исходные данные представляют собой временной ряд. Интервал данных составляет 10 минут.

# %% [markdown]
# Посмотрим на общее описание данных и проверим пропуски и дубли

# %%
display(df_taxi.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 26496 entries, 2018-03-01 00:00:00 to 2018-08-31 23:50:00
# Data columns (total 1 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   num_orders  26496 non-null  int64
# dtypes: int64(1)
# memory usage: 414.0 KB
# None

# %% [markdown]
# 26496 строк в таблице и 26496 не пустых значений, следовательно, пропуски в данных отсутвуют.
# Количество заказов - целое число, как и должно быть.
# Посмотрим на общую статистику таблицы.

# %%
display(df_taxi['num_orders'].describe())
# Out:
# count    26496.000000
# mean        14.070463
# std          9.211330
# min          0.000000
# 25%          8.000000
# 50%         13.000000
# 75%         19.000000
# max        119.000000
# Name: num_orders, dtype: float64

# %% [markdown]
# Фиксируем, что в поле количества заказов **присутствуют 0-е значения**.
# Подсчитаем их количество.

# %%
display(df_taxi.query('num_orders==0').count())
# Out:
# num_orders    537
# dtype: int64

# %% [markdown]
# Таких записей оказалось 537 штук, но в данном случае это допустимо, потому что в какие-то интервалы действительно могло и не быть заказов, так что ничего удалять не будем.
#
# Посмотрим на даты.

# %%
display(df_taxi.index.min(),df_taxi.index.max())
# Out:
# Timestamp('2018-03-01 00:00:00')
# Timestamp('2018-08-31 23:50:00')

# %% [markdown]
# У нас в наборе данные за **период с 1 марта 2018 по 31 августа 2018 года**.
#
# Теперь проверим дублирование записей.

# %%
display(f'Дублированных строк без учета индекса: {df_taxi.duplicated().sum()}')
display(f'Дублированных индексов: {df_taxi.index.duplicated().sum()}')
# Out:
# 'Дублированных строк без учета индекса: 26415'
# 'Дублированных индексов: 0'

# %%
# проверим наши индексы на монотонность
df_taxi.index.is_monotonic
# Out:
# True

# %% [markdown]
# Получается, что дублей в индексах нет, их последовательность монотонна, то есть они отсортированы по порядку, а дублирование количества заказов нас не интересует, потому что в нашем случае это нормально.

# %% [markdown]
# Промежуточный вывод по результатам предварительного анализа данных:
# - количество записей составляет 26496,
# - пропусков в данных нет,
# - дублирования данных нет,
# - данные представлены за период 1 марта 2018 по 31 августа 2018 года,
# - минимальное количество поездок равно 0, максимальное - 119,
# - аномальных значений нет.

# %% [markdown]
# Знакомство с данными мы провели, теперь **перейдем к их ресемплингу на интервалы в 1 час и исследованию**, чтобы подготовиться к построению модели машинного обучения.

# %%
# строим график временного ряда
df_taxi.plot(ax=plt.gca())
plt.title('Временной ряд до ресемплинга на интервалы в 1 час')
plt.tight_layout()

# %%
df_taxi_res = df_taxi.resample('1h').sum()
df_taxi_res.plot(ax=plt.gca())
plt.title('Временной ряд после ресемплинга на интервалы в 1 час')
plt.tight_layout()

# %% [markdown]
# Посмотрим на статистику данных после ресемплинга

# %%
# посмотрим на статистику данных
display(df_taxi_res.describe())
# Out:
#         num_orders
# count  4416.000000
# mean     84.422781
# std      45.023853
# min       0.000000
# 25%      54.000000
# 50%      78.000000
# 75%     107.000000
# max     462.000000

# %%
# посмотрим на общую информацию
display(df_taxi_res.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 4416 entries, 2018-03-01 00:00:00 to 2018-08-31 23:00:00
# Freq: H
# Data columns (total 1 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   num_orders  4416 non-null   int64
# dtypes: int64(1)
# memory usage: 69.0 KB
# None

# %% [markdown]
# Итоговый вывод по результатам загрузки данных и предобработки:
# - количество записей после ресемплинга сократилось с 26496 до 4416,
# - пропусков в данных и пустых значений нет,
# - данные представлены за период 1 марта 2018 по 31 августа 2018 года,
# - количество поездок:
#     - до ресемплинга за период в 10 минут от 0 до 119,
#     - после ресемплинга за период в 1 час от 0 до 462,
# - аномальных значений нет.

# %% [markdown]
# ## Анализ

# %% [markdown]
# Определим, стационарен ли наш ряд. Для этого используем тест Дики-Фулера.

# %%
# проведем тест Дики-Фуллера, чтобы определить природу нашего исходного ряда
st_test = adfuller(df_taxi_res['num_orders'], regression='ctt')

if st_test[1] < 0.05:
    print('Наш ряд стационарный')
else:
    print('Ряд нестационарный')
# Out:
# Наш ряд стационарный

# %% [markdown]
# Далее вычислим скользящее среднее для нашего ряда и посмотрим на тренды и сезонность данных.

# %%
# вычисляем скользящее среднее
taxi_temp = df_taxi_res.copy()
taxi_temp['rolling_mean'] = taxi_temp.rolling(30).mean()
taxi_temp.plot(ax=plt.gca())
plt.title('Скользящее среднее')
plt.tight_layout()

# %% [markdown]
# Видим, что среднее количество заказов растет от марта к августу. Делаем вывод, что наш ряд нестационарный.

# %%
# посмотрим на тренды
decomposed = seasonal_decompose(df_taxi_res)
decomposed.trend.plot(ax=plt.gca())
plt.title('Тренды поездок такси')
plt.tight_layout()

# %% [markdown]
# Видим тренд на увеличение количества поездок на такси от марта к августу.

# %%
# посмотрим на сезонность в разрезе месяца
decomposed.seasonal['2018-03-01':'2018-03-15'].plot(ax=plt.gca())
plt.title('Сезонность поездок такси в разрезе 15 дней')
plt.tight_layout()

# %% [markdown]
# Сезонность выше, чем 1 день, увеличим масштаб, чтобы ее рассмотреть

# %%
# посмотрим на сезонность в разрезе дня
decomposed.seasonal['2018-03-01':'2018-03-02'].plot(ax=plt.gca())
plt.title('Сезонность поездок такси в разрезе 2 дней')
plt.tight_layout()

# %% [markdown]
# Видим, что пик приходится на 24:00, затем идет резкий спад до 06:00 и опять начинается рост спроса с провалами в 12:00 и 18:00.
# Поскольку наш ряд нестационарный, то рассчитаем временную разность, чтобы сделать его более стационарным.

# %%
# рассчитаем временную разность
taxi_temp = taxi_temp - taxi_temp.shift()
taxi_temp['mean'] = taxi_temp['num_orders'].rolling(30).mean()
taxi_temp['std'] = taxi_temp['num_orders'].rolling(30).std()
taxi_temp.plot(ax=plt.gca())
plt.title('Временная разность в разрезе всего объема данных')
plt.show()

# %%
# увеличим масштаб, чтобы рассмотреть график
taxi_temp['2018-03-01':'2018-03-15'].plot(ax=plt.gca())
plt.title('Временная разность в разрезе 15 дней')
plt.show()

# %% [markdown]
# **Выводы:**
# - наблюдается тренд на рост числа заказов от марта к августу,
# - наблюдается сезонность: пик приходится на 24:00, затем идет резкий спад до 06:00 и опять начинается рост спроса с провалами в 12:00 и 18:00,
# - тестом Дики-Фулера мы определили, что наш ряд стационарный, проигнорировав заметный рост числа заказов в августе, но тем не менее будем учить модель на данных с временной разностью.

# %%
# код ревьювера
from statsmodels.tsa.stattools import adfuller

taxi = pd.read_csv("/datasets/taxi.csv", index_col=[0], parse_dates=[0]).resample('1H').sum()

ts = taxi['num_orders']
st_test = adfuller(ts, regression='ctt')

print('Если значение с индексом 1 меньше P-Value, заданное нами (обычно берут 0.05), то ряд стационарный')
if st_test[1] < 0.05:
    print('Наш ряд стационарный')
else:
    print('Ряд нестационарный')
# Out:
# Если значение с индексом 1 меньше P-Value, заданное нами (обычно берут 0.05), то ряд стационарный
# Наш ряд стационарный

# %% [markdown]
# ## Обучение

# %% [markdown]
# Обучим следующие модели:
# - LinearRegression,
# - DecisionTreeRegressor,
# - CatBoostRegressor.

# %% [markdown]
# Создадим функцию, которая будет добавлять дополнительные признаки, необходимые модели для обучения. Поскольку выше мы установили, что наша сезонность суточная, то в качестве дополнительного признака мы добавим день и час.

# %%
def make_features(data, max_lag, rolling_mean_size):
    data['day'] = data.index.day
    data['dayofweek'] = data.index.dayofweek
    data['hour'] = data.index.hour
    
    for lag in range(1, max_lag + 1):
        data['lag_{}'.format(lag)] = data['num_orders'].shift(lag)

    data['rolling_mean'] = data['num_orders'].shift().rolling(rolling_mean_size).mean()

# %%
# создаем признаки с помощью функции и задаем параметры
MAX_LAG = 24
ROLLING_MEAN_SIZE = 24
RANDOM_STATE = 42
make_features(df_taxi_res, MAX_LAG, ROLLING_MEAN_SIZE)

# %%
# Код ревьюера
from statsmodels.graphics import tsaplots

taxi = pd.read_csv("/datasets/taxi.csv", index_col=[0], parse_dates=[0]).resample('1H').sum()
ts = taxi['num_orders']

fig = tsaplots.plot_acf(ts,lags= 190)
fig.set_size_inches(18.5, 6)
plt.ylim(-.1, 1.1)
plt.show()

# %%
# делим наши данные на тренировочную и тестовую выборки
train, test = train_test_split(df_taxi_res, shuffle=False, test_size=0.1)
train = train.dropna()

# %%
# напечатаем индексы выборок, чтобы проверить деление
print(train.index.min(), train.index.max())
print(test.index.min(), test.index.max())
# Out:
# 2018-03-02 00:00:00 2018-08-13 13:00:00
# 2018-08-13 14:00:00 2018-08-31 23:00:00

# %% [markdown]
# Деление прошло корректно.

# %%
# делим наши данные на тренировочную и тестовую выборки
X_train = train.drop('num_orders', axis=1)
y_train = train['num_orders']
X_test = test.drop('num_orders', axis=1)
y_test = test['num_orders']

# %% [markdown]
# Для поиска лучшей модели воспользуемся кросс-валидацией для временных рядов.

# %%
tscv = TimeSeriesSplit(n_splits=5)

# %% [markdown]
# ### Модель линейной регрессии

# %%
model_lr = LinearRegression()
param_search_lr = {}

# %%
grid_lr = GridSearchCV(estimator=model_lr, cv=tscv, param_grid=param_search_lr, scoring= 'neg_mean_squared_error')
grid_lr.fit(X_test, y_test)
# Out:
# GridSearchCV(cv=TimeSeriesSplit(gap=0, max_train_size=None, n_splits=5, test_size=None),
#              estimator=LinearRegression(), param_grid={},
#              scoring='neg_mean_squared_error')

# %%
# выводим на экран параметры лучшей модели для LinearRegression
print('Лучшая модель и её параметры:\n\n', grid_lr.best_estimator_)
print (f'Метрика MSE лучшей модели, полученная кросс-валидацией: {grid_lr.best_score_: .2f}')
print (f'Метрика RMSE лучшей модели, полученная кросс-валидацией: {(grid_lr.best_score_*-1)**0.5: .2f}')
# Out:
# Лучшая модель и её параметры:
#
#  LinearRegression()
# Метрика MSE лучшей модели, полученная кросс-валидацией: -2164.82
# Метрика RMSE лучшей модели, полученная кросс-валидацией:  46.53

# %% [markdown]
# **RMSE на кросс-валидации: 46.53**

# %% [markdown]
# ### Модель дерева решений

# %%
model_dtr = DecisionTreeRegressor(random_state=RANDOM_STATE)
param_search_dtr = {
    'criterion':['friedman_mse'],
    'max_depth':range(2,7),
    'min_samples_leaf':range(2,7)    
}

# %%
grid_dtr = GridSearchCV(estimator=model_dtr, cv=tscv, param_grid=param_search_dtr, scoring= 'neg_mean_squared_error')
grid_dtr.fit(X_test, y_test)
# Out:
# GridSearchCV(cv=TimeSeriesSplit(gap=0, max_train_size=None, n_splits=5, test_size=None),
#              estimator=DecisionTreeRegressor(random_state=42),
#              param_grid={'criterion': ['friedman_mse'],
#                          'max_depth': range(2, 7),
#                          'min_samples_leaf': range(2, 7)},
#              scoring='neg_mean_squared_error')

# %%
# выводим на экран параметры лучшей модели для LinearRegression
print('Лучшая модель и её параметры:\n\n', grid_dtr.best_estimator_)
print (f'Метрика MSE лучшей модели, полученная кросс-валидацией: {grid_dtr.best_score_: .2f}')
print (f'Метрика RMSE лучшей модели, полученная кросс-валидацией: {(grid_dtr.best_score_*-1)**0.5: .2f}')
# Out:
# Лучшая модель и её параметры:
#
#  DecisionTreeRegressor(criterion='friedman_mse', max_depth=4, min_samples_leaf=5,
#                       random_state=42)
# Метрика MSE лучшей модели, полученная кросс-валидацией: -2247.51
# Метрика RMSE лучшей модели, полученная кросс-валидацией:  47.41

# %% [markdown]
# **RMSE на кросс-валидации: 47.51**

# %% [markdown]
# ### Модель CatBoostRegressor

# %%
model_cbr = CatBoostRegressor(random_state=RANDOM_STATE)
param_search_cbr = {
    'learning_rate':[0.5]    
}

# %%
grid_cbr = GridSearchCV(estimator=model_cbr, cv=tscv, param_grid=param_search_cbr,
                        verbose=False, scoring= 'neg_mean_squared_error')
grid_cbr.fit(X_test, y_test)
# Out:
# 0:	learn: 40.1183668	total: 49.1ms	remaining: 49s
# 1:	learn: 34.1527529	total: 50.9ms	remaining: 25.4s
# 2:	learn: 29.6275231	total: 52.6ms	remaining: 17.5s
# 3:	learn: 25.8254792	total: 54.3ms	remaining: 13.5s
# 4:	learn: 23.7323698	total: 56ms	remaining: 11.1s
# 5:	learn: 20.4608465	total: 57.7ms	remaining: 9.56s
# 6:	learn: 17.7875514	total: 59.4ms	remaining: 8.43s
# 7:	learn: 16.1212564	total: 61.1ms	remaining: 7.57s
# 8:	learn: 14.3642561	total: 62.8ms	remaining: 6.92s
# 9:	learn: 12.9782729	total: 64.6ms	remaining: 6.39s
# 10:	learn: 12.2800625	total: 66.3ms	remaining: 5.96s
# 11:	learn: 10.6494140	total: 67.9ms	remaining: 5.59s
# 12:	learn: 9.0604415	total: 69.7ms	remaining: 5.29s
# 13:	learn: 8.3365907	total: 71.5ms	remaining: 5.03s
# 14:	learn: 7.4547641	total: 73.3ms	remaining: 4.82s
# 15:	learn: 6.4677274	total: 75ms	remaining: 4.61s
# 16:	learn: 5.7755987	total: 76.7ms	remaining: 4.44s
# 17:	learn: 4.9682600	total: 78.6ms	remaining: 4.29s
# 18:	learn: 4.7460196	total: 80.3ms	remaining: 4.15s
# 19:	learn: 4.0481845	total: 82.1ms	remaining: 4.02s
# 20:	learn: 3.4302561	total: 83.8ms	remaining: 3.91s
# 21:	learn: 2.9167891	total: 85.6ms	remaining: 3.8s
# 22:	learn: 2.4679177	total: 87.3ms	remaining: 3.71s
# 23:	learn: 2.2139101	total: 89ms	remaining: 3.62s
# 24:	learn: 2.1030019	total: 90.7ms	remaining: 3.54s
# 25:	learn: 1.7888159	total: 92.2ms	remaining: 3.45s
# 26:	learn: 1.7151422	total: 93.9ms	remaining: 3.38s
# 27:	learn: 1.5291648	total: 96ms	remaining: 3.33s
# 28:	learn: 1.3480867	total: 97.8ms	remaining: 3.27s
# 29:	learn: 1.1601537	total: 99.4ms	remaining: 3.21s
# 30:	learn: 0.9981456	total: 101ms	remaining: 3.17s
# 31:	learn: 0.8497287	total: 103ms	remaining: 3.11s
# 32:	learn: 0.7427482	total: 105ms	remaining: 3.06s
# 33:	learn: 0.6434269	total: 106ms	remaining: 3.02s
# 34:	learn: 0.6117589	total: 108ms	remaining: 2.98s
# 35:	learn: 0.5206648	total: 110ms	remaining: 2.94s
# 36:	learn: 0.4621765	total: 112ms	remaining: 2.9s
# 37:	learn: 0.4049857	total: 113ms	remaining: 2.86s
# 38:	learn: 0.3716452	total: 115ms	remaining: 2.83s
# 39:	learn: 0.3112834	total: 117ms	remaining: 2.8s
# 40:	learn: 0.2588426	total: 118ms	remaining: 2.77s
# 41:	learn: 0.2170952	total: 121ms	remaining: 2.75s
# 42:	learn: 0.1867108	total: 122ms	remaining: 2.72s
# 43:	learn: 0.1583616	total: 124ms	remaining: 2.7s
# 44:	learn: 0.1330042	total: 126ms	remaining: 2.67s
# 45:	learn: 0.1265745	total: 128ms	remaining: 2.65s
# 46:	learn: 0.1074941	total: 130ms	remaining: 2.63s
# 47:	learn: 0.0914094	total: 131ms	remaining: 2.6s
# 48:	learn: 0.0791334	total: 133ms	remaining: 2.58s
# 49:	learn: 0.0694323	total: 135ms	remaining: 2.56s
# 50:	learn: 0.0637073	total: 137ms	remaining: 2.54s
# 51:	learn: 0.0541456	total: 138ms	remaining: 2.52s
# 52:	learn: 0.0465209	total: 140ms	remaining: 2.5s
# 53:	learn: 0.0424915	total: 142ms	remaining: 2.48s
# 54:	learn: 0.0366546	total: 143ms	remaining: 2.46s
# 55:	learn: 0.0330098	total: 145ms	remaining: 2.44s
# 56:	learn: 0.0319277	total: 147ms	remaining: 2.43s
# 57:	learn: 0.0297354	total: 148ms	remaining: 2.41s
# 58:	learn: 0.0259056	total: 150ms	remaining: 2.39s
# 59:	learn: 0.0234611	total: 152ms	remaining: 2.38s
# 60:	learn: 0.0196381	total: 154ms	remaining: 2.36s
# 61:	learn: 0.0165163	total: 155ms	remaining: 2.35s
# 62:	learn: 0.0140230	total: 157ms	remaining: 2.33s
# 63:	learn: 0.0136196	total: 159ms	remaining: 2.32s
# 64:	learn: 0.0119839	total: 160ms	remaining: 2.31s
# 65:	learn: 0.0104057	total: 162ms	remaining: 2.29s
# 66:	learn: 0.0091276	total: 164ms	remaining: 2.28s
# 67:	learn: 0.0078950	total: 165ms	remaining: 2.27s
# 68:	learn: 0.0069450	total: 167ms	remaining: 2.26s
# 69:	learn: 0.0059469	total: 169ms	remaining: 2.24s
# 70:	learn: 0.0054041	total: 171ms	remaining: 2.23s
# 71:	learn: 0.0048155	total: 172ms	remaining: 2.22s
# 72:	learn: 0.0041882	total: 174ms	remaining: 2.21s
# 73:	learn: 0.0036106	total: 176ms	remaining: 2.2s
# 74:	learn: 0.0030464	total: 177ms	remaining: 2.19s
# 75:	learn: 0.0026772	total: 179ms	remaining: 2.18s
# 76:	learn: 0.0023333	total: 181ms	remaining: 2.17s
# 77:	learn: 0.0020079	total: 182ms	remaining: 2.16s
# 78:	learn: 0.0017378	total: 184ms	remaining: 2.15s
# 79:	learn: 0.0015719	total: 185ms	remaining: 2.13s
# 80:	learn: 0.0013607	total: 187ms	remaining: 2.12s
# 81:	learn: 0.0011758	total: 189ms	remaining: 2.11s
# 82:	learn: 0.0011346	total: 190ms	remaining: 2.1s
# 83:	learn: 0.0010458	total: 192ms	remaining: 2.09s
# 84:	learn: 0.0010197	total: 194ms	remaining: 2.08s
# 85:	learn: 0.0008749	total: 195ms	remaining: 2.08s
# 86:	learn: 0.0007837	total: 197ms	remaining: 2.07s
# 87:	learn: 0.0006714	total: 199ms	remaining: 2.06s
# 88:	learn: 0.0005878	total: 201ms	remaining: 2.05s
# 89:	learn: 0.0005017	total: 202ms	remaining: 2.04s
# 90:	learn: 0.0004472	total: 204ms	remaining: 2.04s
# 91:	learn: 0.0004064	total: 206ms	remaining: 2.03s
# 92:	learn: 0.0003499	total: 207ms	remaining: 2.02s
# 93:	learn: 0.0003332	total: 209ms	remaining: 2.02s
# 94:	learn: 0.0002987	total: 211ms	remaining: 2.01s
# 95:	learn: 0.0002898	total: 213ms	remaining: 2s
# 96:	learn: 0.0002818	total: 214ms	remaining: 1.99s
# 97:	learn: 0.0002434	total: 216ms	remaining: 1.99s
# 98:	learn: 0.0002111	total: 218ms	remaining: 1.98s
# 99:	learn: 0.0001805	total: 219ms	remaining: 1.97s
# 100:	learn: 0.0001524	total: 221ms	remaining: 1.97s
# 101:	learn: 0.0001334	total: 223ms	remaining: 1.96s
# 102:	learn: 0.0001122	total: 225ms	remaining: 1.96s
# 103:	learn: 0.0000967	total: 227ms	remaining: 1.96s
# 104:	learn: 0.0000874	total: 229ms	remaining: 1.95s
# 105:	learn: 0.0000812	total: 231ms	remaining: 1.94s
# 106:	learn: 0.0000778	total: 232ms	remaining: 1.94s
# 107:	learn: 0.0000685	total: 234ms	remaining: 1.93s
# 108:	learn: 0.0000597	total: 236ms	remaining: 1.93s
# 109:	learn: 0.0000504	total: 237ms	remaining: 1.92s
# 110:	learn: 0.0000432	total: 239ms	remaining: 1.91s
# 111:	learn: 0.0000375	total: 240ms	remaining: 1.91s
# 112:	learn: 0.0000325	total: 242ms	remaining: 1.9s
# 113:	learn: 0.0000289	total: 244ms	remaining: 1.9s
# 114:	learn: 0.0000270	total: 246ms	remaining: 1.89s
# 115:	learn: 0.0000237	total: 247ms	remaining: 1.88s
# 116:	learn: 0.0000229	total: 249ms	remaining: 1.88s
# 117:	learn: 0.0000211	total: 251ms	remaining: 1.87s
# 118:	learn: 0.0000184	total: 252ms	remaining: 1.87s
# 119:	learn: 0.0000163	total: 254ms	remaining: 1.86s
# 120:	learn: 0.0000150	total: 256ms	remaining: 1.86s
# 121:	learn: 0.0000140	total: 258ms	remaining: 1.85s
# 122:	learn: 0.0000133	total: 259ms	remaining: 1.85s
# 123:	learn: 0.0000129	total: 261ms	remaining: 1.84s
# 124:	learn: 0.0000123	total: 262ms	remaining: 1.84s
# 125:	learn: 0.0000117	total: 264ms	remaining: 1.83s
# 126:	learn: 0.0000101	total: 266ms	remaining: 1.83s
# 127:	learn: 0.0000089	total: 267ms	remaining: 1.82s
# 128:	learn: 0.0000077	total: 269ms	remaining: 1.82s
# 129:	learn: 0.0000067	total: 271ms	remaining: 1.81s
# 130:	learn: 0.0000063	total: 273ms	remaining: 1.81s
# 131:	learn: 0.0000057	total: 274ms	remaining: 1.8s
# 132:	learn: 0.0000055	total: 276ms	remaining: 1.8s
# 133:	learn: 0.0000046	total: 278ms	remaining: 1.79s
# 134:	learn: 0.0000041	total: 279ms	remaining: 1.79s
# 135:	learn: 0.0000040	total: 281ms	remaining: 1.78s
# 136:	learn: 0.0000035	total: 283ms	remaining: 1.78s
# 137:	learn: 0.0000032	total: 284ms	remaining: 1.78s
# 138:	learn: 0.0000029	total: 286ms	remaining: 1.77s
# 139:	learn: 0.0000026	total: 288ms	remaining: 1.77s
# 140:	learn: 0.0000025	total: 289ms	remaining: 1.76s
# 141:	learn: 0.0000024	total: 291ms	remaining: 1.76s
# 142:	learn: 0.0000021	total: 292ms	remaining: 1.75s
# 143:	learn: 0.0000018	total: 294ms	remaining: 1.75s
# 144:	learn: 0.0000017	total: 295ms	remaining: 1.74s
# 145:	learn: 0.0000014	total: 297ms	remaining: 1.74s
# 146:	learn: 0.0000012	total: 299ms	remaining: 1.73s
# 147:	learn: 0.0000012	total: 300ms	remaining: 1.73s
# 148:	learn: 0.0000010	total: 302ms	remaining: 1.73s
# 149:	learn: 0.0000009	total: 304ms	remaining: 1.72s
# 150:	learn: 0.0000008	total: 306ms	remaining: 1.72s
# 151:	learn: 0.0000007	total: 307ms	remaining: 1.71s
# 152:	learn: 0.0000006	total: 309ms	remaining: 1.71s
# 153:	learn: 0.0000006	total: 311ms	remaining: 1.71s
# 154:	learn: 0.0000005	total: 312ms	remaining: 1.7s
# 155:	learn: 0.0000005	total: 314ms	remaining: 1.7s
# 156:	learn: 0.0000004	total: 315ms	remaining: 1.69s
# 157:	learn: 0.0000004	total: 317ms	remaining: 1.69s
# 158:	learn: 0.0000003	total: 319ms	remaining: 1.69s
# 159:	learn: 0.0000003	total: 321ms	remaining: 1.68s
# 160:	learn: 0.0000003	total: 323ms	remaining: 1.68s
# 161:	learn: 0.0000002	total: 325ms	remaining: 1.68s
# 162:	learn: 0.0000002	total: 327ms	remaining: 1.68s
# 163:	learn: 0.0000002	total: 329ms	remaining: 1.68s
# 164:	learn: 0.0000002	total: 330ms	remaining: 1.67s
# 165:	learn: 0.0000002	total: 332ms	remaining: 1.67s
# 166:	learn: 0.0000001	total: 334ms	remaining: 1.67s
# 167:	learn: 0.0000001	total: 336ms	remaining: 1.66s
# 168:	learn: 0.0000001	total: 337ms	remaining: 1.66s
# 169:	learn: 0.0000001	total: 339ms	remaining: 1.65s
# 170:	learn: 0.0000001	total: 341ms	remaining: 1.65s
# 171:	learn: 0.0000001	total: 342ms	remaining: 1.65s
# 172:	learn: 0.0000001	total: 344ms	remaining: 1.64s
# 173:	learn: 0.0000001	total: 346ms	remaining: 1.64s
# 174:	learn: 0.0000001	total: 347ms	remaining: 1.64s
# 175:	learn: 0.0000001	total: 349ms	remaining: 1.63s
# 176:	learn: 0.0000001	total: 351ms	remaining: 1.63s
# 177:	learn: 0.0000001	total: 353ms	remaining: 1.63s
# 178:	learn: 0.0000001	total: 355ms	remaining: 1.63s
# 179:	learn: 0.0000000	total: 356ms	remaining: 1.62s
# 180:	learn: 0.0000000	total: 358ms	remaining: 1.62s
# 181:	learn: 0.0000000	total: 360ms	remaining: 1.62s
# 182:	learn: 0.0000000	total: 362ms	remaining: 1.61s
# 183:	learn: 0.0000000	total: 363ms	remaining: 1.61s
# 184:	learn: 0.0000000	total: 365ms	remaining: 1.61s
# 185:	learn: 0.0000000	total: 367ms	remaining: 1.6s
# 186:	learn: 0.0000000	total: 369ms	remaining: 1.6s
# 187:	learn: 0.0000000	total: 371ms	remaining: 1.6s
# 188:	learn: 0.0000000	total: 373ms	remaining: 1.6s
# 189:	learn: 0.0000000	total: 375ms	remaining: 1.6s
# 190:	learn: 0.0000000	total: 377ms	remaining: 1.59s
# 191:	learn: 0.0000000	total: 378ms	remaining: 1.59s
# 192:	learn: 0.0000000	total: 380ms	remaining: 1.59s
# 193:	learn: 0.0000000	total: 381ms	remaining: 1.58s
# 194:	learn: 0.0000000	total: 383ms	remaining: 1.58s
# 195:	learn: 0.0000000	total: 385ms	remaining: 1.58s
# 196:	learn: 0.0000000	total: 386ms	remaining: 1.57s
# 197:	learn: 0.0000000	total: 388ms	remaining: 1.57s
# 198:	learn: 0.0000000	total: 390ms	remaining: 1.57s
# 199:	learn: 0.0000000	total: 391ms	remaining: 1.56s
# 200:	learn: 0.0000000	total: 393ms	remaining: 1.56s
# 201:	learn: 0.0000000	total: 394ms	remaining: 1.56s
# 202:	learn: 0.0000000	total: 396ms	remaining: 1.55s
# 203:	learn: 0.0000000	total: 398ms	remaining: 1.55s
# 204:	learn: 0.0000000	total: 400ms	remaining: 1.55s
# 205:	learn: 0.0000000	total: 402ms	remaining: 1.55s
# 206:	learn: 0.0000000	total: 403ms	remaining: 1.54s
# 207:	learn: 0.0000000	total: 405ms	remaining: 1.54s
# 208:	learn: 0.0000000	total: 407ms	remaining: 1.54s
# 209:	learn: 0.0000000	total: 408ms	remaining: 1.54s
# 210:	learn: 0.0000000	total: 410ms	remaining: 1.53s
# 211:	learn: 0.0000000	total: 412ms	remaining: 1.53s
# 212:	learn: 0.0000000	total: 414ms	remaining: 1.53s
# 213:	learn: 0.0000000	total: 416ms	remaining: 1.53s
# 214:	learn: 0.0000000	total: 417ms	remaining: 1.52s
# 215:	learn: 0.0000000	total: 419ms	remaining: 1.52s
# 216:	learn: 0.0000000	total: 421ms	remaining: 1.52s
# 217:	learn: 0.0000000	total: 422ms	remaining: 1.51s
# 218:	learn: 0.0000000	total: 424ms	remaining: 1.51s
# 219:	learn: 0.0000000	total: 426ms	remaining: 1.51s
# 220:	learn: 0.0000000	total: 427ms	remaining: 1.51s
# 221:	learn: 0.0000000	total: 429ms	remaining: 1.5s
# 222:	learn: 0.0000000	total: 431ms	remaining: 1.5s
# 223:	learn: 0.0000000	total: 432ms	remaining: 1.5s
# 224:	learn: 0.0000000	total: 434ms	remaining: 1.5s
# 225:	learn: 0.0000000	total: 436ms	remaining: 1.49s
# 226:	learn: 0.0000000	total: 438ms	remaining: 1.49s
# 227:	learn: 0.0000000	total: 439ms	remaining: 1.49s
# 228:	learn: 0.0000000	total: 441ms	remaining: 1.48s
# 229:	learn: 0.0000000	total: 443ms	remaining: 1.48s
# 230:	learn: 0.0000000	total: 444ms	remaining: 1.48s
# 231:	learn: 0.0000000	total: 446ms	remaining: 1.48s
# 232:	learn: 0.0000000	total: 448ms	remaining: 1.47s
# 233:	learn: 0.0000000	total: 449ms	remaining: 1.47s
# 234:	learn: 0.0000000	total: 451ms	remaining: 1.47s
# 235:	learn: 0.0000000	total: 453ms	remaining: 1.47s
# 236:	learn: 0.0000000	total: 455ms	remaining: 1.46s
# 237:	learn: 0.0000000	total: 456ms	remaining: 1.46s
# 238:	learn: 0.0000000	total: 458ms	remaining: 1.46s
# 239:	learn: 0.0000000	total: 460ms	remaining: 1.46s
# 240:	learn: 0.0000000	total: 462ms	remaining: 1.45s
# 241:	learn: 0.0000000	total: 463ms	remaining: 1.45s
# 242:	learn: 0.0000000	total: 465ms	remaining: 1.45s
# 243:	learn: 0.0000000	total: 467ms	remaining: 1.45s
# 244:	learn: 0.0000000	total: 468ms	remaining: 1.44s
# 245:	learn: 0.0000000	total: 470ms	remaining: 1.44s
# 246:	learn: 0.0000000	total: 472ms	remaining: 1.44s
# 247:	learn: 0.0000000	total: 473ms	remaining: 1.44s
# 248:	learn: 0.0000000	total: 476ms	remaining: 1.43s
# 249:	learn: 0.0000000	total: 478ms	remaining: 1.43s
# 250:	learn: 0.0000000	total: 479ms	remaining: 1.43s
# 251:	learn: 0.0000000	total: 481ms	remaining: 1.43s
# 252:	learn: 0.0000000	total: 483ms	remaining: 1.43s
# 253:	learn: 0.0000000	total: 485ms	remaining: 1.42s
# 254:	learn: 0.0000000	total: 486ms	remaining: 1.42s
# 255:	learn: 0.0000000	total: 488ms	remaining: 1.42s
# 256:	learn: 0.0000000	total: 490ms	remaining: 1.42s
# 257:	learn: 0.0000000	total: 492ms	remaining: 1.41s
# 258:	learn: 0.0000000	total: 494ms	remaining: 1.41s
# 259:	learn: 0.0000000	total: 495ms	remaining: 1.41s
# 260:	learn: 0.0000000	total: 497ms	remaining: 1.41s
# 261:	learn: 0.0000000	total: 499ms	remaining: 1.4s
# 262:	learn: 0.0000000	total: 500ms	remaining: 1.4s
# 263:	learn: 0.0000000	total: 502ms	remaining: 1.4s
# 264:	learn: 0.0000000	total: 504ms	remaining: 1.4s
# 265:	learn: 0.0000000	total: 505ms	remaining: 1.39s
# 266:	learn: 0.0000000	total: 507ms	remaining: 1.39s
# 267:	learn: 0.0000000	total: 509ms	remaining: 1.39s
# 268:	learn: 0.0000000	total: 511ms	remaining: 1.39s
# 269:	learn: 0.0000000	total: 512ms	remaining: 1.39s
# 270:	learn: 0.0000000	total: 514ms	remaining: 1.38s
# 271:	learn: 0.0000000	total: 516ms	remaining: 1.38s
# 272:	learn: 0.0000000	total: 518ms	remaining: 1.38s
# 273:	learn: 0.0000000	total: 519ms	remaining: 1.38s
# 274:	learn: 0.0000000	total: 521ms	remaining: 1.37s
# 275:	learn: 0.0000000	total: 523ms	remaining: 1.37s
# 276:	learn: 0.0000000	total: 524ms	remaining: 1.37s
# 277:	learn: 0.0000000	total: 526ms	remaining: 1.37s
# 278:	learn: 0.0000000	total: 528ms	remaining: 1.36s
# 279:	learn: 0.0000000	total: 529ms	remaining: 1.36s
# 280:	learn: 0.0000000	total: 531ms	remaining: 1.36s
# 281:	learn: 0.0000000	total: 533ms	remaining: 1.36s
# 282:	learn: 0.0000000	total: 535ms	remaining: 1.35s
# 283:	learn: 0.0000000	total: 536ms	remaining: 1.35s
# 284:	learn: 0.0000000	total: 538ms	remaining: 1.35s
# 285:	learn: 0.0000000	total: 540ms	remaining: 1.35s
# 286:	learn: 0.0000000	total: 542ms	remaining: 1.35s
# 287:	learn: 0.0000000	total: 544ms	remaining: 1.34s
# 288:	learn: 0.0000000	total: 545ms	remaining: 1.34s
# 289:	learn: 0.0000000	total: 547ms	remaining: 1.34s
# 290:	learn: 0.0000000	total: 549ms	remaining: 1.34s
# 291:	learn: 0.0000000	total: 550ms	remaining: 1.33s
# 292:	learn: 0.0000000	total: 552ms	remaining: 1.33s
# 293:	learn: 0.0000000	total: 554ms	remaining: 1.33s
# 294:	learn: 0.0000000	total: 555ms	remaining: 1.33s
# 295:	learn: 0.0000000	total: 557ms	remaining: 1.32s
# 296:	learn: 0.0000000	total: 559ms	remaining: 1.32s
# 297:	learn: 0.0000000	total: 561ms	remaining: 1.32s
# 298:	learn: 0.0000000	total: 562ms	remaining: 1.32s
# 299:	learn: 0.0000000	total: 564ms	remaining: 1.32s
# 300:	learn: 0.0000000	total: 566ms	remaining: 1.31s
# 301:	learn: 0.0000000	total: 567ms	remaining: 1.31s
# 302:	learn: 0.0000000	total: 569ms	remaining: 1.31s
# 303:	learn: 0.0000000	total: 571ms	remaining: 1.31s
# 304:	learn: 0.0000000	total: 573ms	remaining: 1.3s
# 305:	learn: 0.0000000	total: 574ms	remaining: 1.3s
# 306:	learn: 0.0000000	total: 576ms	remaining: 1.3s
# 307:	learn: 0.0000000	total: 578ms	remaining: 1.3s
# 308:	learn: 0.0000000	total: 580ms	remaining: 1.3s
# 309:	learn: 0.0000000	total: 581ms	remaining: 1.29s
# 310:	learn: 0.0000000	total: 583ms	remaining: 1.29s
# 311:	learn: 0.0000000	total: 585ms	remaining: 1.29s
# 312:	learn: 0.0000000	total: 586ms	remaining: 1.29s
# 313:	learn: 0.0000000	total: 589ms	remaining: 1.28s
# 314:	learn: 0.0000000	total: 590ms	remaining: 1.28s
# 315:	learn: 0.0000000	total: 593ms	remaining: 1.28s
# 316:	learn: 0.0000000	total: 595ms	remaining: 1.28s
# 317:	learn: 0.0000000	total: 596ms	remaining: 1.28s
# 318:	learn: 0.0000000	total: 598ms	remaining: 1.28s
# 319:	learn: 0.0000000	total: 600ms	remaining: 1.27s
# 320:	learn: 0.0000000	total: 602ms	remaining: 1.27s
# 321:	learn: 0.0000000	total: 603ms	remaining: 1.27s
# 322:	learn: 0.0000000	total: 605ms	remaining: 1.27s
# 323:	learn: 0.0000000	total: 607ms	remaining: 1.26s
# 324:	learn: 0.0000000	total: 608ms	remaining: 1.26s
# 325:	learn: 0.0000000	total: 610ms	remaining: 1.26s
# 326:	learn: 0.0000000	total: 612ms	remaining: 1.26s
# 327:	learn: 0.0000000	total: 613ms	remaining: 1.26s
# 328:	learn: 0.0000000	total: 615ms	remaining: 1.25s
# 329:	learn: 0.0000000	total: 617ms	remaining: 1.25s
# 330:	learn: 0.0000000	total: 619ms	remaining: 1.25s
# 331:	learn: 0.0000000	total: 621ms	remaining: 1.25s
# 332:	learn: 0.0000000	total: 622ms	remaining: 1.25s
# 333:	learn: 0.0000000	total: 624ms	remaining: 1.24s
# 334:	learn: 0.0000000	total: 625ms	remaining: 1.24s
# 335:	learn: 0.0000000	total: 627ms	remaining: 1.24s
# 336:	learn: 0.0000000	total: 629ms	remaining: 1.24s
# 337:	learn: 0.0000000	total: 630ms	remaining: 1.23s
# 338:	learn: 0.0000000	total: 632ms	remaining: 1.23s
# 339:	learn: 0.0000000	total: 634ms	remaining: 1.23s
# 340:	learn: 0.0000000	total: 636ms	remaining: 1.23s
# 341:	learn: 0.0000000	total: 637ms	remaining: 1.23s
# 342:	learn: 0.0000000	total: 639ms	remaining: 1.22s
# 343:	learn: 0.0000000	total: 641ms	remaining: 1.22s
# 344:	learn: 0.0000000	total: 642ms	remaining: 1.22s
# 345:	learn: 0.0000000	total: 644ms	remaining: 1.22s
# 346:	learn: 0.0000000	total: 646ms	remaining: 1.22s
# 347:	learn: 0.0000000	total: 648ms	remaining: 1.21s
# 348:	learn: 0.0000000	total: 649ms	remaining: 1.21s
# 349:	learn: 0.0000000	total: 651ms	remaining: 1.21s
# 350:	learn: 0.0000000	total: 652ms	remaining: 1.21s
# 351:	learn: 0.0000000	total: 654ms	remaining: 1.2s
# 352:	learn: 0.0000000	total: 656ms	remaining: 1.2s
# 353:	learn: 0.0000000	total: 657ms	remaining: 1.2s
# 354:	learn: 0.0000000	total: 659ms	remaining: 1.2s
# 355:	learn: 0.0000000	total: 660ms	remaining: 1.19s
# 356:	learn: 0.0000000	total: 662ms	remaining: 1.19s
# 357:	learn: 0.0000000	total: 664ms	remaining: 1.19s
# 358:	learn: 0.0000000	total: 666ms	remaining: 1.19s
# 359:	learn: 0.0000000	total: 667ms	remaining: 1.19s
# 360:	learn: 0.0000000	total: 669ms	remaining: 1.18s
# 361:	learn: 0.0000000	total: 671ms	remaining: 1.18s
# 362:	learn: 0.0000000	total: 672ms	remaining: 1.18s
# 363:	learn: 0.0000000	total: 674ms	remaining: 1.18s
# 364:	learn: 0.0000000	total: 676ms	remaining: 1.18s
# 365:	learn: 0.0000000	total: 677ms	remaining: 1.17s
# 366:	learn: 0.0000000	total: 679ms	remaining: 1.17s
# 367:	learn: 0.0000000	total: 681ms	remaining: 1.17s
# 368:	learn: 0.0000000	total: 682ms	remaining: 1.17s
# 369:	learn: 0.0000000	total: 684ms	remaining: 1.16s
# 370:	learn: 0.0000000	total: 686ms	remaining: 1.16s
# 371:	learn: 0.0000000	total: 687ms	remaining: 1.16s
# 372:	learn: 0.0000000	total: 689ms	remaining: 1.16s
# 373:	learn: 0.0000000	total: 691ms	remaining: 1.16s
# 374:	learn: 0.0000000	total: 692ms	remaining: 1.15s
# 375:	learn: 0.0000000	total: 694ms	remaining: 1.15s
# 376:	learn: 0.0000000	total: 695ms	remaining: 1.15s
# 377:	learn: 0.0000000	total: 697ms	remaining: 1.15s
# 378:	learn: 0.0000000	total: 698ms	remaining: 1.14s
# 379:	learn: 0.0000000	total: 700ms	remaining: 1.14s
# 380:	learn: 0.0000000	total: 702ms	remaining: 1.14s
# 381:	learn: 0.0000000	total: 704ms	remaining: 1.14s
# 382:	learn: 0.0000000	total: 705ms	remaining: 1.14s
# 383:	learn: 0.0000000	total: 707ms	remaining: 1.13s
# 384:	learn: 0.0000000	total: 708ms	remaining: 1.13s
# 385:	learn: 0.0000000	total: 710ms	remaining: 1.13s
# 386:	learn: 0.0000000	total: 712ms	remaining: 1.13s
# 387:	learn: 0.0000000	total: 713ms	remaining: 1.13s
# 388:	learn: 0.0000000	total: 715ms	remaining: 1.12s
# 389:	learn: 0.0000000	total: 717ms	remaining: 1.12s
# 390:	learn: 0.0000000	total: 718ms	remaining: 1.12s
# 391:	learn: 0.0000000	total: 720ms	remaining: 1.12s
# 392:	learn: 0.0000000	total: 721ms	remaining: 1.11s
# 393:	learn: 0.0000000	total: 723ms	remaining: 1.11s
# 394:	learn: 0.0000000	total: 725ms	remaining: 1.11s
# 395:	learn: 0.0000000	total: 726ms	remaining: 1.11s
# 396:	learn: 0.0000000	total: 728ms	remaining: 1.1s
# 397:	learn: 0.0000000	total: 730ms	remaining: 1.1s
# 398:	learn: 0.0000000	total: 731ms	remaining: 1.1s
# 399:	learn: 0.0000000	total: 733ms	remaining: 1.1s
# 400:	learn: 0.0000000	total: 735ms	remaining: 1.1s
# 401:	learn: 0.0000000	total: 736ms	remaining: 1.09s
# 402:	learn: 0.0000000	total: 738ms	remaining: 1.09s
# 403:	learn: 0.0000000	total: 739ms	remaining: 1.09s
# 404:	learn: 0.0000000	total: 741ms	remaining: 1.09s
# 405:	learn: 0.0000000	total: 743ms	remaining: 1.09s
# 406:	learn: 0.0000000	total: 744ms	remaining: 1.08s
# 407:	learn: 0.0000000	total: 746ms	remaining: 1.08s
# 408:	learn: 0.0000000	total: 748ms	remaining: 1.08s
# 409:	learn: 0.0000000	total: 749ms	remaining: 1.08s
# 410:	learn: 0.0000000	total: 751ms	remaining: 1.08s
# 411:	learn: 0.0000000	total: 753ms	remaining: 1.07s
# 412:	learn: 0.0000000	total: 754ms	remaining: 1.07s
# 413:	learn: 0.0000000	total: 756ms	remaining: 1.07s
# 414:	learn: 0.0000000	total: 758ms	remaining: 1.07s
# 415:	learn: 0.0000000	total: 759ms	remaining: 1.07s
# 416:	learn: 0.0000000	total: 761ms	remaining: 1.06s
# 417:	learn: 0.0000000	total: 763ms	remaining: 1.06s
# 418:	learn: 0.0000000	total: 764ms	remaining: 1.06s
# 419:	learn: 0.0000000	total: 766ms	remaining: 1.06s
# 420:	learn: 0.0000000	total: 767ms	remaining: 1.05s
# 421:	learn: 0.0000000	total: 769ms	remaining: 1.05s
# 422:	learn: 0.0000000	total: 771ms	remaining: 1.05s
# 423:	learn: 0.0000000	total: 772ms	remaining: 1.05s
# 424:	learn: 0.0000000	total: 774ms	remaining: 1.05s
# 425:	learn: 0.0000000	total: 776ms	remaining: 1.04s
# 426:	learn: 0.0000000	total: 777ms	remaining: 1.04s
# 427:	learn: 0.0000000	total: 779ms	remaining: 1.04s
# 428:	learn: 0.0000000	total: 780ms	remaining: 1.04s
# 429:	learn: 0.0000000	total: 782ms	remaining: 1.04s
# 430:	learn: 0.0000000	total: 784ms	remaining: 1.03s
# 431:	learn: 0.0000000	total: 785ms	remaining: 1.03s
# 432:	learn: 0.0000000	total: 787ms	remaining: 1.03s
# 433:	learn: 0.0000000	total: 789ms	remaining: 1.03s
# 434:	learn: 0.0000000	total: 790ms	remaining: 1.03s
# 435:	learn: 0.0000000	total: 792ms	remaining: 1.02s
# 436:	learn: 0.0000000	total: 793ms	remaining: 1.02s
# 437:	learn: 0.0000000	total: 795ms	remaining: 1.02s
# 438:	learn: 0.0000000	total: 797ms	remaining: 1.02s
# 439:	learn: 0.0000000	total: 799ms	remaining: 1.02s
# 440:	learn: 0.0000000	total: 800ms	remaining: 1.01s
# 441:	learn: 0.0000000	total: 802ms	remaining: 1.01s
# 442:	learn: 0.0000000	total: 804ms	remaining: 1.01s
# 443:	learn: 0.0000000	total: 806ms	remaining: 1.01s
# 444:	learn: 0.0000000	total: 808ms	remaining: 1.01s
# 445:	learn: 0.0000000	total: 810ms	remaining: 1s
# 446:	learn: 0.0000000	total: 812ms	remaining: 1s
# 447:	learn: 0.0000000	total: 814ms	remaining: 1s
# 448:	learn: 0.0000000	total: 816ms	remaining: 1s
# 449:	learn: 0.0000000	total: 817ms	remaining: 999ms
# 450:	learn: 0.0000000	total: 819ms	remaining: 997ms
# 451:	learn: 0.0000000	total: 821ms	remaining: 995ms
# 452:	learn: 0.0000000	total: 822ms	remaining: 993ms
# 453:	learn: 0.0000000	total: 824ms	remaining: 991ms
# 454:	learn: 0.0000000	total: 826ms	remaining: 989ms
# 455:	learn: 0.0000000	total: 827ms	remaining: 987ms
# 456:	learn: 0.0000000	total: 829ms	remaining: 985ms
# 457:	learn: 0.0000000	total: 831ms	remaining: 983ms
# 458:	learn: 0.0000000	total: 832ms	remaining: 981ms
# 459:	learn: 0.0000000	total: 834ms	remaining: 979ms
# 460:	learn: 0.0000000	total: 836ms	remaining: 977ms
# 461:	learn: 0.0000000	total: 837ms	remaining: 975ms
# 462:	learn: 0.0000000	total: 839ms	remaining: 973ms
# 463:	learn: 0.0000000	total: 841ms	remaining: 971ms
# 464:	learn: 0.0000000	total: 842ms	remaining: 969ms
# 465:	learn: 0.0000000	total: 844ms	remaining: 967ms
# 466:	learn: 0.0000000	total: 846ms	remaining: 966ms
# 467:	learn: 0.0000000	total: 848ms	remaining: 964ms
# 468:	learn: 0.0000000	total: 849ms	remaining: 962ms
# 469:	learn: 0.0000000	total: 851ms	remaining: 960ms
# 470:	learn: 0.0000000	total: 853ms	remaining: 958ms
# 471:	learn: 0.0000000	total: 854ms	remaining: 956ms
# 472:	learn: 0.0000000	total: 856ms	remaining: 954ms
# 473:	learn: 0.0000000	total: 858ms	remaining: 952ms
# 474:	learn: 0.0000000	total: 859ms	remaining: 950ms
# 475:	learn: 0.0000000	total: 861ms	remaining: 948ms
# 476:	learn: 0.0000000	total: 863ms	remaining: 946ms
# 477:	learn: 0.0000000	total: 864ms	remaining: 944ms
# 478:	learn: 0.0000000	total: 866ms	remaining: 942ms
# 479:	learn: 0.0000000	total: 868ms	remaining: 940ms
# 480:	learn: 0.0000000	total: 869ms	remaining: 938ms
# 481:	learn: 0.0000000	total: 871ms	remaining: 936ms
# 482:	learn: 0.0000000	total: 873ms	remaining: 934ms
# 483:	learn: 0.0000000	total: 875ms	remaining: 933ms
# 484:	learn: 0.0000000	total: 876ms	remaining: 931ms
# 485:	learn: 0.0000000	total: 878ms	remaining: 929ms
# 486:	learn: 0.0000000	total: 880ms	remaining: 927ms
# 487:	learn: 0.0000000	total: 882ms	remaining: 925ms
# 488:	learn: 0.0000000	total: 884ms	remaining: 923ms
# 489:	learn: 0.0000000	total: 885ms	remaining: 921ms
# 490:	learn: 0.0000000	total: 887ms	remaining: 920ms
# 491:	learn: 0.0000000	total: 889ms	remaining: 918ms
# 492:	learn: 0.0000000	total: 890ms	remaining: 916ms
# 493:	learn: 0.0000000	total: 892ms	remaining: 914ms
# 494:	learn: 0.0000000	total: 894ms	remaining: 912ms
# 495:	learn: 0.0000000	total: 895ms	remaining: 910ms
# 496:	learn: 0.0000000	total: 897ms	remaining: 908ms
# 497:	learn: 0.0000000	total: 899ms	remaining: 906ms
# 498:	learn: 0.0000000	total: 900ms	remaining: 904ms
# 499:	learn: 0.0000000	total: 902ms	remaining: 902ms
# 500:	learn: 0.0000000	total: 904ms	remaining: 900ms
# 501:	learn: 0.0000000	total: 906ms	remaining: 899ms
# 502:	learn: 0.0000000	total: 908ms	remaining: 897ms
# 503:	learn: 0.0000000	total: 909ms	remaining: 895ms
# 504:	learn: 0.0000000	total: 911ms	remaining: 893ms
# 505:	learn: 0.0000000	total: 913ms	remaining: 891ms
# 506:	learn: 0.0000000	total: 914ms	remaining: 889ms
# 507:	learn: 0.0000000	total: 916ms	remaining: 887ms
# 508:	learn: 0.0000000	total: 918ms	remaining: 885ms
# 509:	learn: 0.0000000	total: 919ms	remaining: 883ms
# 510:	learn: 0.0000000	total: 921ms	remaining: 881ms
# 511:	learn: 0.0000000	total: 922ms	remaining: 879ms
# 512:	learn: 0.0000000	total: 924ms	remaining: 877ms
# 513:	learn: 0.0000000	total: 926ms	remaining: 876ms
# 514:	learn: 0.0000000	total: 928ms	remaining: 874ms
# 515:	learn: 0.0000000	total: 929ms	remaining: 872ms
# 516:	learn: 0.0000000	total: 932ms	remaining: 870ms
# 517:	learn: 0.0000000	total: 934ms	remaining: 869ms
# 518:	learn: 0.0000000	total: 935ms	remaining: 867ms
# 519:	learn: 0.0000000	total: 937ms	remaining: 865ms
# 520:	learn: 0.0000000	total: 939ms	remaining: 863ms
# 521:	learn: 0.0000000	total: 940ms	remaining: 861ms
# 522:	learn: 0.0000000	total: 942ms	remaining: 859ms
# 523:	learn: 0.0000000	total: 943ms	remaining: 857ms
# 524:	learn: 0.0000000	total: 945ms	remaining: 855ms
# 525:	learn: 0.0000000	total: 947ms	remaining: 853ms
# 526:	learn: 0.0000000	total: 948ms	remaining: 851ms
# 527:	learn: 0.0000000	total: 950ms	remaining: 849ms
# 528:	learn: 0.0000000	total: 952ms	remaining: 847ms
# 529:	learn: 0.0000000	total: 953ms	remaining: 845ms
# 530:	learn: 0.0000000	total: 955ms	remaining: 843ms
# 531:	learn: 0.0000000	total: 956ms	remaining: 841ms
# 532:	learn: 0.0000000	total: 958ms	remaining: 839ms
# 533:	learn: 0.0000000	total: 960ms	remaining: 837ms
# 534:	learn: 0.0000000	total: 961ms	remaining: 836ms
# 535:	learn: 0.0000000	total: 963ms	remaining: 834ms
# 536:	learn: 0.0000000	total: 964ms	remaining: 832ms
# 537:	learn: 0.0000000	total: 966ms	remaining: 830ms
# 538:	learn: 0.0000000	total: 968ms	remaining: 828ms
# 539:	learn: 0.0000000	total: 970ms	remaining: 826ms
# 540:	learn: 0.0000000	total: 971ms	remaining: 824ms
# 541:	learn: 0.0000000	total: 973ms	remaining: 822ms
# 542:	learn: 0.0000000	total: 975ms	remaining: 820ms
# 543:	learn: 0.0000000	total: 976ms	remaining: 818ms
# 544:	learn: 0.0000000	total: 978ms	remaining: 816ms
# 545:	learn: 0.0000000	total: 979ms	remaining: 814ms
# 546:	learn: 0.0000000	total: 981ms	remaining: 812ms
# 547:	learn: 0.0000000	total: 983ms	remaining: 810ms
# 548:	learn: 0.0000000	total: 984ms	remaining: 809ms
# 549:	learn: 0.0000000	total: 986ms	remaining: 807ms
# 550:	learn: 0.0000000	total: 987ms	remaining: 805ms
# 551:	learn: 0.0000000	total: 989ms	remaining: 803ms
# 552:	learn: 0.0000000	total: 991ms	remaining: 801ms
# 553:	learn: 0.0000000	total: 992ms	remaining: 799ms
# 554:	learn: 0.0000000	total: 994ms	remaining: 797ms
# 555:	learn: 0.0000000	total: 995ms	remaining: 795ms
# 556:	learn: 0.0000000	total: 997ms	remaining: 793ms
# 557:	learn: 0.0000000	total: 999ms	remaining: 791ms
# 558:	learn: 0.0000000	total: 1s	remaining: 789ms
# 559:	learn: 0.0000000	total: 1s	remaining: 787ms
# 560:	learn: 0.0000000	total: 1s	remaining: 786ms
# 561:	learn: 0.0000000	total: 1s	remaining: 784ms
# 562:	learn: 0.0000000	total: 1.01s	remaining: 782ms
# 563:	learn: 0.0000000	total: 1.01s	remaining: 780ms
# 564:	learn: 0.0000000	total: 1.01s	remaining: 779ms
# 565:	learn: 0.0000000	total: 1.01s	remaining: 777ms
# 566:	learn: 0.0000000	total: 1.01s	remaining: 775ms
# 567:	learn: 0.0000000	total: 1.02s	remaining: 773ms
# 568:	learn: 0.0000000	total: 1.02s	remaining: 771ms
# 569:	learn: 0.0000000	total: 1.02s	remaining: 769ms
# 570:	learn: 0.0000000	total: 1.02s	remaining: 767ms
# 571:	learn: 0.0000000	total: 1.02s	remaining: 766ms
# 572:	learn: 0.0000000	total: 1.02s	remaining: 764ms
# 573:	learn: 0.0000000	total: 1.03s	remaining: 762ms
# 574:	learn: 0.0000000	total: 1.03s	remaining: 760ms
# 575:	learn: 0.0000000	total: 1.03s	remaining: 758ms
# 576:	learn: 0.0000000	total: 1.03s	remaining: 756ms
# 577:	learn: 0.0000000	total: 1.03s	remaining: 754ms
# 578:	learn: 0.0000000	total: 1.03s	remaining: 753ms
# 579:	learn: 0.0000000	total: 1.04s	remaining: 751ms
# 580:	learn: 0.0000000	total: 1.04s	remaining: 749ms
# 581:	learn: 0.0000000	total: 1.04s	remaining: 747ms
# 582:	learn: 0.0000000	total: 1.04s	remaining: 745ms
# 583:	learn: 0.0000000	total: 1.04s	remaining: 743ms
# 584:	learn: 0.0000000	total: 1.04s	remaining: 741ms
# 585:	learn: 0.0000000	total: 1.05s	remaining: 739ms
# 586:	learn: 0.0000000	total: 1.05s	remaining: 737ms
# 587:	learn: 0.0000000	total: 1.05s	remaining: 735ms
# 588:	learn: 0.0000000	total: 1.05s	remaining: 733ms
# 589:	learn: 0.0000000	total: 1.05s	remaining: 732ms
# 590:	learn: 0.0000000	total: 1.05s	remaining: 730ms
# 591:	learn: 0.0000000	total: 1.05s	remaining: 728ms
# 592:	learn: 0.0000000	total: 1.06s	remaining: 726ms
# 593:	learn: 0.0000000	total: 1.06s	remaining: 724ms
# 594:	learn: 0.0000000	total: 1.06s	remaining: 722ms
# 595:	learn: 0.0000000	total: 1.06s	remaining: 720ms
# 596:	learn: 0.0000000	total: 1.06s	remaining: 718ms
# 597:	learn: 0.0000000	total: 1.06s	remaining: 716ms
# 598:	learn: 0.0000000	total: 1.07s	remaining: 715ms
# 599:	learn: 0.0000000	total: 1.07s	remaining: 713ms
# 600:	learn: 0.0000000	total: 1.07s	remaining: 711ms
# 601:	learn: 0.0000000	total: 1.07s	remaining: 709ms
# 602:	learn: 0.0000000	total: 1.07s	remaining: 707ms
# 603:	learn: 0.0000000	total: 1.07s	remaining: 705ms
# 604:	learn: 0.0000000	total: 1.08s	remaining: 703ms
# 605:	learn: 0.0000000	total: 1.08s	remaining: 702ms
# 606:	learn: 0.0000000	total: 1.08s	remaining: 700ms
# 607:	learn: 0.0000000	total: 1.08s	remaining: 698ms
# 608:	learn: 0.0000000	total: 1.08s	remaining: 696ms
# 609:	learn: 0.0000000	total: 1.08s	remaining: 694ms
# 610:	learn: 0.0000000	total: 1.09s	remaining: 692ms
# 611:	learn: 0.0000000	total: 1.09s	remaining: 690ms
# 612:	learn: 0.0000000	total: 1.09s	remaining: 689ms
# 613:	learn: 0.0000000	total: 1.09s	remaining: 687ms
# 614:	learn: 0.0000000	total: 1.09s	remaining: 685ms
# 615:	learn: 0.0000000	total: 1.09s	remaining: 683ms
# 616:	learn: 0.0000000	total: 1.1s	remaining: 681ms
# 617:	learn: 0.0000000	total: 1.1s	remaining: 679ms
# 618:	learn: 0.0000000	total: 1.1s	remaining: 677ms
# 619:	learn: 0.0000000	total: 1.1s	remaining: 675ms
# 620:	learn: 0.0000000	total: 1.1s	remaining: 673ms
# 621:	learn: 0.0000000	total: 1.1s	remaining: 672ms
# 622:	learn: 0.0000000	total: 1.11s	remaining: 670ms
# 623:	learn: 0.0000000	total: 1.11s	remaining: 669ms
# 624:	learn: 0.0000000	total: 1.11s	remaining: 667ms
# 625:	learn: 0.0000000	total: 1.11s	remaining: 666ms
# 626:	learn: 0.0000000	total: 1.12s	remaining: 664ms
# 627:	learn: 0.0000000	total: 1.12s	remaining: 662ms
# 628:	learn: 0.0000000	total: 1.12s	remaining: 660ms
# 629:	learn: 0.0000000	total: 1.12s	remaining: 658ms
# 630:	learn: 0.0000000	total: 1.12s	remaining: 657ms
# 631:	learn: 0.0000000	total: 1.12s	remaining: 655ms
# 632:	learn: 0.0000000	total: 1.13s	remaining: 653ms
# 633:	learn: 0.0000000	total: 1.13s	remaining: 651ms
# 634:	learn: 0.0000000	total: 1.13s	remaining: 649ms
# 635:	learn: 0.0000000	total: 1.13s	remaining: 648ms
# 636:	learn: 0.0000000	total: 1.13s	remaining: 646ms
# 637:	learn: 0.0000000	total: 1.13s	remaining: 644ms
# 638:	learn: 0.0000000	total: 1.14s	remaining: 642ms
# 639:	learn: 0.0000000	total: 1.14s	remaining: 640ms
# 640:	learn: 0.0000000	total: 1.14s	remaining: 638ms
# 641:	learn: 0.0000000	total: 1.14s	remaining: 637ms
# 642:	learn: 0.0000000	total: 1.14s	remaining: 635ms
# 643:	learn: 0.0000000	total: 1.15s	remaining: 633ms
# 644:	learn: 0.0000000	total: 1.15s	remaining: 631ms
# 645:	learn: 0.0000000	total: 1.15s	remaining: 630ms
# 646:	learn: 0.0000000	total: 1.15s	remaining: 628ms
# 647:	learn: 0.0000000	total: 1.15s	remaining: 626ms
# 648:	learn: 0.0000000	total: 1.15s	remaining: 624ms
# 649:	learn: 0.0000000	total: 1.16s	remaining: 623ms
# 650:	learn: 0.0000000	total: 1.16s	remaining: 621ms
# 651:	learn: 0.0000000	total: 1.16s	remaining: 619ms
# 652:	learn: 0.0000000	total: 1.16s	remaining: 617ms
# 653:	learn: 0.0000000	total: 1.16s	remaining: 616ms
# 654:	learn: 0.0000000	total: 1.17s	remaining: 614ms
# 655:	learn: 0.0000000	total: 1.17s	remaining: 612ms
# 656:	learn: 0.0000000	total: 1.17s	remaining: 610ms
# 657:	learn: 0.0000000	total: 1.17s	remaining: 609ms
# 658:	learn: 0.0000000	total: 1.17s	remaining: 607ms
# 659:	learn: 0.0000000	total: 1.18s	remaining: 605ms
# 660:	learn: 0.0000000	total: 1.18s	remaining: 604ms
# 661:	learn: 0.0000000	total: 1.18s	remaining: 602ms
# 662:	learn: 0.0000000	total: 1.18s	remaining: 600ms
# 663:	learn: 0.0000000	total: 1.18s	remaining: 598ms
# 664:	learn: 0.0000000	total: 1.18s	remaining: 597ms
# 665:	learn: 0.0000000	total: 1.19s	remaining: 595ms
# 666:	learn: 0.0000000	total: 1.19s	remaining: 593ms
# 667:	learn: 0.0000000	total: 1.19s	remaining: 591ms
# 668:	learn: 0.0000000	total: 1.19s	remaining: 589ms
# 669:	learn: 0.0000000	total: 1.19s	remaining: 588ms
# 670:	learn: 0.0000000	total: 1.19s	remaining: 586ms
# 671:	learn: 0.0000000	total: 1.2s	remaining: 584ms
# 672:	learn: 0.0000000	total: 1.2s	remaining: 582ms
# 673:	learn: 0.0000000	total: 1.2s	remaining: 580ms
# 674:	learn: 0.0000000	total: 1.2s	remaining: 579ms
# 675:	learn: 0.0000000	total: 1.2s	remaining: 577ms
# 676:	learn: 0.0000000	total: 1.2s	remaining: 575ms
# 677:	learn: 0.0000000	total: 1.21s	remaining: 573ms
# 678:	learn: 0.0000000	total: 1.21s	remaining: 571ms
# 679:	learn: 0.0000000	total: 1.21s	remaining: 569ms
# 680:	learn: 0.0000000	total: 1.21s	remaining: 568ms
# 681:	learn: 0.0000000	total: 1.21s	remaining: 566ms
# 682:	learn: 0.0000000	total: 1.22s	remaining: 564ms
# 683:	learn: 0.0000000	total: 1.22s	remaining: 562ms
# 684:	learn: 0.0000000	total: 1.22s	remaining: 560ms
# 685:	learn: 0.0000000	total: 1.22s	remaining: 559ms
# 686:	learn: 0.0000000	total: 1.22s	remaining: 557ms
# 687:	learn: 0.0000000	total: 1.22s	remaining: 555ms
# 688:	learn: 0.0000000	total: 1.23s	remaining: 553ms
# 689:	learn: 0.0000000	total: 1.23s	remaining: 551ms
# 690:	learn: 0.0000000	total: 1.23s	remaining: 550ms
# 691:	learn: 0.0000000	total: 1.23s	remaining: 548ms
# 692:	learn: 0.0000000	total: 1.23s	remaining: 546ms
# 693:	learn: 0.0000000	total: 1.23s	remaining: 544ms
# 694:	learn: 0.0000000	total: 1.24s	remaining: 542ms
# 695:	learn: 0.0000000	total: 1.24s	remaining: 540ms
# 696:	learn: 0.0000000	total: 1.24s	remaining: 539ms
# 697:	learn: 0.0000000	total: 1.24s	remaining: 537ms
# 698:	learn: 0.0000000	total: 1.24s	remaining: 535ms
# 699:	learn: 0.0000000	total: 1.24s	remaining: 533ms
# 700:	learn: 0.0000000	total: 1.25s	remaining: 532ms
# 701:	learn: 0.0000000	total: 1.25s	remaining: 530ms
# 702:	learn: 0.0000000	total: 1.25s	remaining: 528ms
# 703:	learn: 0.0000000	total: 1.25s	remaining: 526ms
# 704:	learn: 0.0000000	total: 1.25s	remaining: 525ms
# 705:	learn: 0.0000000	total: 1.25s	remaining: 523ms
# 706:	learn: 0.0000000	total: 1.26s	remaining: 521ms
# 707:	learn: 0.0000000	total: 1.26s	remaining: 519ms
# 708:	learn: 0.0000000	total: 1.26s	remaining: 517ms
# 709:	learn: 0.0000000	total: 1.26s	remaining: 516ms
# 710:	learn: 0.0000000	total: 1.26s	remaining: 514ms
# 711:	learn: 0.0000000	total: 1.26s	remaining: 512ms
# 712:	learn: 0.0000000	total: 1.27s	remaining: 510ms
# 713:	learn: 0.0000000	total: 1.27s	remaining: 508ms
# 714:	learn: 0.0000000	total: 1.27s	remaining: 507ms
# 715:	learn: 0.0000000	total: 1.27s	remaining: 505ms
# 716:	learn: 0.0000000	total: 1.27s	remaining: 503ms
# 717:	learn: 0.0000000	total: 1.28s	remaining: 501ms
# 718:	learn: 0.0000000	total: 1.28s	remaining: 499ms
# 719:	learn: 0.0000000	total: 1.28s	remaining: 498ms
# 720:	learn: 0.0000000	total: 1.28s	remaining: 496ms
# 721:	learn: 0.0000000	total: 1.28s	remaining: 494ms
# 722:	learn: 0.0000000	total: 1.28s	remaining: 492ms
# 723:	learn: 0.0000000	total: 1.29s	remaining: 490ms
# 724:	learn: 0.0000000	total: 1.29s	remaining: 489ms
# 725:	learn: 0.0000000	total: 1.29s	remaining: 487ms
# 726:	learn: 0.0000000	total: 1.29s	remaining: 485ms
# 727:	learn: 0.0000000	total: 1.29s	remaining: 483ms
# 728:	learn: 0.0000000	total: 1.29s	remaining: 482ms
# 729:	learn: 0.0000000	total: 1.3s	remaining: 480ms
# 730:	learn: 0.0000000	total: 1.3s	remaining: 478ms
# 731:	learn: 0.0000000	total: 1.3s	remaining: 476ms
# 732:	learn: 0.0000000	total: 1.3s	remaining: 474ms
# 733:	learn: 0.0000000	total: 1.3s	remaining: 472ms
# 734:	learn: 0.0000000	total: 1.3s	remaining: 471ms
# 735:	learn: 0.0000000	total: 1.31s	remaining: 469ms
# 736:	learn: 0.0000000	total: 1.31s	remaining: 467ms
# 737:	learn: 0.0000000	total: 1.31s	remaining: 465ms
# 738:	learn: 0.0000000	total: 1.31s	remaining: 463ms
# 739:	learn: 0.0000000	total: 1.31s	remaining: 462ms
# 740:	learn: 0.0000000	total: 1.31s	remaining: 460ms
# 741:	learn: 0.0000000	total: 1.32s	remaining: 458ms
# 742:	learn: 0.0000000	total: 1.32s	remaining: 456ms
# 743:	learn: 0.0000000	total: 1.32s	remaining: 454ms
# 744:	learn: 0.0000000	total: 1.32s	remaining: 452ms
# 745:	learn: 0.0000000	total: 1.32s	remaining: 451ms
# 746:	learn: 0.0000000	total: 1.32s	remaining: 449ms
# 747:	learn: 0.0000000	total: 1.33s	remaining: 447ms
# 748:	learn: 0.0000000	total: 1.33s	remaining: 445ms
# 749:	learn: 0.0000000	total: 1.33s	remaining: 443ms
# 750:	learn: 0.0000000	total: 1.33s	remaining: 441ms
# 751:	learn: 0.0000000	total: 1.33s	remaining: 440ms
# 752:	learn: 0.0000000	total: 1.33s	remaining: 438ms
# 753:	learn: 0.0000000	total: 1.34s	remaining: 436ms
# 754:	learn: 0.0000000	total: 1.34s	remaining: 434ms
# 755:	learn: 0.0000000	total: 1.34s	remaining: 433ms
# 756:	learn: 0.0000000	total: 1.34s	remaining: 431ms
# 757:	learn: 0.0000000	total: 1.34s	remaining: 429ms
# 758:	learn: 0.0000000	total: 1.34s	remaining: 427ms
# 759:	learn: 0.0000000	total: 1.35s	remaining: 426ms
# 760:	learn: 0.0000000	total: 1.35s	remaining: 424ms
# 761:	learn: 0.0000000	total: 1.35s	remaining: 422ms
# 762:	learn: 0.0000000	total: 1.35s	remaining: 420ms
# 763:	learn: 0.0000000	total: 1.35s	remaining: 418ms
# 764:	learn: 0.0000000	total: 1.36s	remaining: 417ms
# 765:	learn: 0.0000000	total: 1.36s	remaining: 415ms
# 766:	learn: 0.0000000	total: 1.36s	remaining: 413ms
# 767:	learn: 0.0000000	total: 1.36s	remaining: 411ms
# 768:	learn: 0.0000000	total: 1.36s	remaining: 409ms
# 769:	learn: 0.0000000	total: 1.36s	remaining: 408ms
# 770:	learn: 0.0000000	total: 1.37s	remaining: 406ms
# 771:	learn: 0.0000000	total: 1.37s	remaining: 404ms
# 772:	learn: 0.0000000	total: 1.37s	remaining: 402ms
# 773:	learn: 0.0000000	total: 1.37s	remaining: 401ms
# 774:	learn: 0.0000000	total: 1.37s	remaining: 399ms
# 775:	learn: 0.0000000	total: 1.38s	remaining: 397ms
# 776:	learn: 0.0000000	total: 1.38s	remaining: 395ms
# 777:	learn: 0.0000000	total: 1.38s	remaining: 394ms
# 778:	learn: 0.0000000	total: 1.38s	remaining: 392ms
# 779:	learn: 0.0000000	total: 1.38s	remaining: 390ms
# 780:	learn: 0.0000000	total: 1.38s	remaining: 388ms
# 781:	learn: 0.0000000	total: 1.39s	remaining: 387ms
# 782:	learn: 0.0000000	total: 1.39s	remaining: 385ms
# 783:	learn: 0.0000000	total: 1.39s	remaining: 383ms
# 784:	learn: 0.0000000	total: 1.39s	remaining: 381ms
# 785:	learn: 0.0000000	total: 1.39s	remaining: 379ms
# 786:	learn: 0.0000000	total: 1.4s	remaining: 378ms
# 787:	learn: 0.0000000	total: 1.4s	remaining: 376ms
# 788:	learn: 0.0000000	total: 1.4s	remaining: 374ms
# 789:	learn: 0.0000000	total: 1.4s	remaining: 372ms
# 790:	learn: 0.0000000	total: 1.4s	remaining: 370ms
# 791:	learn: 0.0000000	total: 1.4s	remaining: 369ms
# 792:	learn: 0.0000000	total: 1.4s	remaining: 367ms
# 793:	learn: 0.0000000	total: 1.41s	remaining: 365ms
# 794:	learn: 0.0000000	total: 1.41s	remaining: 363ms
# 795:	learn: 0.0000000	total: 1.41s	remaining: 361ms
# 796:	learn: 0.0000000	total: 1.41s	remaining: 360ms
# 797:	learn: 0.0000000	total: 1.41s	remaining: 358ms
# 798:	learn: 0.0000000	total: 1.41s	remaining: 356ms
# 799:	learn: 0.0000000	total: 1.42s	remaining: 354ms
# 800:	learn: 0.0000000	total: 1.42s	remaining: 352ms
# 801:	learn: 0.0000000	total: 1.42s	remaining: 351ms
# 802:	learn: 0.0000000	total: 1.42s	remaining: 349ms
# 803:	learn: 0.0000000	total: 1.42s	remaining: 347ms
# 804:	learn: 0.0000000	total: 1.43s	remaining: 345ms
# 805:	learn: 0.0000000	total: 1.43s	remaining: 343ms
# 806:	learn: 0.0000000	total: 1.43s	remaining: 342ms
# 807:	learn: 0.0000000	total: 1.43s	remaining: 340ms
# 808:	learn: 0.0000000	total: 1.43s	remaining: 338ms
# 809:	learn: 0.0000000	total: 1.43s	remaining: 336ms
# 810:	learn: 0.0000000	total: 1.44s	remaining: 335ms
# 811:	learn: 0.0000000	total: 1.44s	remaining: 333ms
# 812:	learn: 0.0000000	total: 1.44s	remaining: 331ms
# 813:	learn: 0.0000000	total: 1.44s	remaining: 329ms
# 814:	learn: 0.0000000	total: 1.44s	remaining: 327ms
# 815:	learn: 0.0000000	total: 1.44s	remaining: 326ms
# 816:	learn: 0.0000000	total: 1.45s	remaining: 324ms
# 817:	learn: 0.0000000	total: 1.45s	remaining: 322ms
# 818:	learn: 0.0000000	total: 1.45s	remaining: 320ms
# 819:	learn: 0.0000000	total: 1.45s	remaining: 318ms
# 820:	learn: 0.0000000	total: 1.45s	remaining: 317ms
# 821:	learn: 0.0000000	total: 1.45s	remaining: 315ms
# 822:	learn: 0.0000000	total: 1.46s	remaining: 313ms
# 823:	learn: 0.0000000	total: 1.46s	remaining: 311ms
# 824:	learn: 0.0000000	total: 1.46s	remaining: 309ms
# 825:	learn: 0.0000000	total: 1.46s	remaining: 308ms
# 826:	learn: 0.0000000	total: 1.46s	remaining: 306ms
# 827:	learn: 0.0000000	total: 1.46s	remaining: 304ms
# 828:	learn: 0.0000000	total: 1.46s	remaining: 302ms
# 829:	learn: 0.0000000	total: 1.47s	remaining: 300ms
# 830:	learn: 0.0000000	total: 1.47s	remaining: 299ms
# 831:	learn: 0.0000000	total: 1.47s	remaining: 297ms
# 832:	learn: 0.0000000	total: 1.47s	remaining: 295ms
# 833:	learn: 0.0000000	total: 1.47s	remaining: 293ms
# 834:	learn: 0.0000000	total: 1.47s	remaining: 291ms
# 835:	learn: 0.0000000	total: 1.48s	remaining: 289ms
# 836:	learn: 0.0000000	total: 1.48s	remaining: 288ms
# 837:	learn: 0.0000000	total: 1.48s	remaining: 286ms
# 838:	learn: 0.0000000	total: 1.48s	remaining: 284ms
# 839:	learn: 0.0000000	total: 1.48s	remaining: 282ms
# 840:	learn: 0.0000000	total: 1.48s	remaining: 281ms
# 841:	learn: 0.0000000	total: 1.49s	remaining: 279ms
# 842:	learn: 0.0000000	total: 1.49s	remaining: 277ms
# 843:	learn: 0.0000000	total: 1.49s	remaining: 275ms
# 844:	learn: 0.0000000	total: 1.49s	remaining: 273ms
# 845:	learn: 0.0000000	total: 1.49s	remaining: 272ms
# 846:	learn: 0.0000000	total: 1.49s	remaining: 270ms
# 847:	learn: 0.0000000	total: 1.5s	remaining: 268ms
# 848:	learn: 0.0000000	total: 1.5s	remaining: 266ms
# 849:	learn: 0.0000000	total: 1.5s	remaining: 264ms
# 850:	learn: 0.0000000	total: 1.5s	remaining: 263ms
# 851:	learn: 0.0000000	total: 1.5s	remaining: 261ms
# 852:	learn: 0.0000000	total: 1.5s	remaining: 259ms
# 853:	learn: 0.0000000	total: 1.5s	remaining: 257ms
# 854:	learn: 0.0000000	total: 1.51s	remaining: 255ms
# 855:	learn: 0.0000000	total: 1.51s	remaining: 254ms
# 856:	learn: 0.0000000	total: 1.51s	remaining: 252ms
# 857:	learn: 0.0000000	total: 1.51s	remaining: 250ms
# 858:	learn: 0.0000000	total: 1.51s	remaining: 248ms
# 859:	learn: 0.0000000	total: 1.51s	remaining: 246ms
# 860:	learn: 0.0000000	total: 1.51s	remaining: 245ms
# 861:	learn: 0.0000000	total: 1.52s	remaining: 243ms
# 862:	learn: 0.0000000	total: 1.52s	remaining: 241ms
# 863:	learn: 0.0000000	total: 1.52s	remaining: 239ms
# 864:	learn: 0.0000000	total: 1.52s	remaining: 238ms
# 865:	learn: 0.0000000	total: 1.52s	remaining: 236ms
# 866:	learn: 0.0000000	total: 1.52s	remaining: 234ms
# 867:	learn: 0.0000000	total: 1.53s	remaining: 232ms
# 868:	learn: 0.0000000	total: 1.53s	remaining: 230ms
# 869:	learn: 0.0000000	total: 1.53s	remaining: 229ms
# 870:	learn: 0.0000000	total: 1.53s	remaining: 227ms
# 871:	learn: 0.0000000	total: 1.53s	remaining: 225ms
# 872:	learn: 0.0000000	total: 1.53s	remaining: 223ms
# 873:	learn: 0.0000000	total: 1.54s	remaining: 222ms
# 874:	learn: 0.0000000	total: 1.54s	remaining: 220ms
# 875:	learn: 0.0000000	total: 1.54s	remaining: 218ms
# 876:	learn: 0.0000000	total: 1.54s	remaining: 216ms
# 877:	learn: 0.0000000	total: 1.54s	remaining: 214ms
# 878:	learn: 0.0000000	total: 1.54s	remaining: 213ms
# 879:	learn: 0.0000000	total: 1.55s	remaining: 211ms
# 880:	learn: 0.0000000	total: 1.55s	remaining: 209ms
# 881:	learn: 0.0000000	total: 1.55s	remaining: 207ms
# 882:	learn: 0.0000000	total: 1.55s	remaining: 206ms
# 883:	learn: 0.0000000	total: 1.55s	remaining: 204ms
# 884:	learn: 0.0000000	total: 1.55s	remaining: 202ms
# 885:	learn: 0.0000000	total: 1.56s	remaining: 200ms
# 886:	learn: 0.0000000	total: 1.56s	remaining: 198ms
# 887:	learn: 0.0000000	total: 1.56s	remaining: 197ms
# 888:	learn: 0.0000000	total: 1.56s	remaining: 195ms
# 889:	learn: 0.0000000	total: 1.56s	remaining: 193ms
# 890:	learn: 0.0000000	total: 1.56s	remaining: 191ms
# 891:	learn: 0.0000000	total: 1.56s	remaining: 190ms
# 892:	learn: 0.0000000	total: 1.57s	remaining: 188ms
# 893:	learn: 0.0000000	total: 1.57s	remaining: 186ms
# 894:	learn: 0.0000000	total: 1.57s	remaining: 184ms
# 895:	learn: 0.0000000	total: 1.57s	remaining: 183ms
# 896:	learn: 0.0000000	total: 1.57s	remaining: 181ms
# 897:	learn: 0.0000000	total: 1.58s	remaining: 179ms
# 898:	learn: 0.0000000	total: 1.58s	remaining: 177ms
# 899:	learn: 0.0000000	total: 1.58s	remaining: 175ms
# 900:	learn: 0.0000000	total: 1.58s	remaining: 174ms
# 901:	learn: 0.0000000	total: 1.58s	remaining: 172ms
# 902:	learn: 0.0000000	total: 1.58s	remaining: 170ms
# 903:	learn: 0.0000000	total: 1.58s	remaining: 168ms
# 904:	learn: 0.0000000	total: 1.59s	remaining: 167ms
# 905:	learn: 0.0000000	total: 1.59s	remaining: 165ms
# 906:	learn: 0.0000000	total: 1.59s	remaining: 163ms
# 907:	learn: 0.0000000	total: 1.59s	remaining: 161ms
# 908:	learn: 0.0000000	total: 1.59s	remaining: 159ms
# 909:	learn: 0.0000000	total: 1.59s	remaining: 158ms
# 910:	learn: 0.0000000	total: 1.6s	remaining: 156ms
# 911:	learn: 0.0000000	total: 1.6s	remaining: 154ms
# 912:	learn: 0.0000000	total: 1.6s	remaining: 152ms
# 913:	learn: 0.0000000	total: 1.6s	remaining: 151ms
# 914:	learn: 0.0000000	total: 1.6s	remaining: 149ms
# 915:	learn: 0.0000000	total: 1.6s	remaining: 147ms
# 916:	learn: 0.0000000	total: 1.6s	remaining: 145ms
# 917:	learn: 0.0000000	total: 1.61s	remaining: 144ms
# 918:	learn: 0.0000000	total: 1.61s	remaining: 142ms
# 919:	learn: 0.0000000	total: 1.61s	remaining: 140ms
# 920:	learn: 0.0000000	total: 1.61s	remaining: 138ms
# 921:	learn: 0.0000000	total: 1.61s	remaining: 137ms
# 922:	learn: 0.0000000	total: 1.61s	remaining: 135ms
# 923:	learn: 0.0000000	total: 1.62s	remaining: 133ms
# 924:	learn: 0.0000000	total: 1.62s	remaining: 131ms
# 925:	learn: 0.0000000	total: 1.62s	remaining: 129ms
# ...
# 698:	learn: 0.0000000	total: 3.91s	remaining: 1.68s
# 699:	learn: 0.0000000	total: 3.92s	remaining: 1.68s
# 700:	learn: 0.0000000	total: 3.92s	remaining: 1.67s
# 701:	learn: 0.0000000	total: 3.93s	remaining: 1.67s
# 702:	learn: 0.0000000	total: 3.94s	remaining: 1.66s
# 703:	learn: 0.0000000	total: 3.94s	remaining: 1.66s
# 704:	learn: 0.0000000	total: 3.95s	remaining: 1.65s
# 705:	learn: 0.0000000	total: 3.96s	remaining: 1.65s
# 706:	learn: 0.0000000	total: 3.96s	remaining: 1.64s
# 707:	learn: 0.0000000	total: 3.97s	remaining: 1.64s
# 708:	learn: 0.0000000	total: 3.97s	remaining: 1.63s
# 709:	learn: 0.0000000	total: 3.98s	remaining: 1.63s
# 710:	learn: 0.0000000	total: 3.98s	remaining: 1.62s
# 711:	learn: 0.0000000	total: 3.99s	remaining: 1.61s
# 712:	learn: 0.0000000	total: 4s	remaining: 1.61s
# 713:	learn: 0.0000000	total: 4s	remaining: 1.6s
# 714:	learn: 0.0000000	total: 4.01s	remaining: 1.6s
# 715:	learn: 0.0000000	total: 4.01s	remaining: 1.59s
# 716:	learn: 0.0000000	total: 4.02s	remaining: 1.59s
# 717:	learn: 0.0000000	total: 4.03s	remaining: 1.58s
# 718:	learn: 0.0000000	total: 4.03s	remaining: 1.57s
# 719:	learn: 0.0000000	total: 4.04s	remaining: 1.57s
# 720:	learn: 0.0000000	total: 4.04s	remaining: 1.56s
# 721:	learn: 0.0000000	total: 4.05s	remaining: 1.56s
# 722:	learn: 0.0000000	total: 4.05s	remaining: 1.55s
# 723:	learn: 0.0000000	total: 4.06s	remaining: 1.55s
# 724:	learn: 0.0000000	total: 4.06s	remaining: 1.54s
# 725:	learn: 0.0000000	total: 4.07s	remaining: 1.54s
# 726:	learn: 0.0000000	total: 4.08s	remaining: 1.53s
# 727:	learn: 0.0000000	total: 4.08s	remaining: 1.52s
# 728:	learn: 0.0000000	total: 4.09s	remaining: 1.52s
# 729:	learn: 0.0000000	total: 4.09s	remaining: 1.51s
# 730:	learn: 0.0000000	total: 4.1s	remaining: 1.51s
# 731:	learn: 0.0000000	total: 4.11s	remaining: 1.5s
# 732:	learn: 0.0000000	total: 4.11s	remaining: 1.5s
# 733:	learn: 0.0000000	total: 4.12s	remaining: 1.49s
# 734:	learn: 0.0000000	total: 4.12s	remaining: 1.49s
# 735:	learn: 0.0000000	total: 4.13s	remaining: 1.48s
# 736:	learn: 0.0000000	total: 4.13s	remaining: 1.47s
# 737:	learn: 0.0000000	total: 4.14s	remaining: 1.47s
# 738:	learn: 0.0000000	total: 4.14s	remaining: 1.46s
# 739:	learn: 0.0000000	total: 4.15s	remaining: 1.46s
# 740:	learn: 0.0000000	total: 4.16s	remaining: 1.45s
# 741:	learn: 0.0000000	total: 4.17s	remaining: 1.45s
# 742:	learn: 0.0000000	total: 4.17s	remaining: 1.44s
# 743:	learn: 0.0000000	total: 4.18s	remaining: 1.44s
# 744:	learn: 0.0000000	total: 4.18s	remaining: 1.43s
# 745:	learn: 0.0000000	total: 4.19s	remaining: 1.43s
# 746:	learn: 0.0000000	total: 4.19s	remaining: 1.42s
# 747:	learn: 0.0000000	total: 4.2s	remaining: 1.41s
# 748:	learn: 0.0000000	total: 4.2s	remaining: 1.41s
# 749:	learn: 0.0000000	total: 4.21s	remaining: 1.4s
# 750:	learn: 0.0000000	total: 4.21s	remaining: 1.4s
# 751:	learn: 0.0000000	total: 4.22s	remaining: 1.39s
# 752:	learn: 0.0000000	total: 4.22s	remaining: 1.39s
# 753:	learn: 0.0000000	total: 4.23s	remaining: 1.38s
# 754:	learn: 0.0000000	total: 4.24s	remaining: 1.38s
# 755:	learn: 0.0000000	total: 4.25s	remaining: 1.37s
# 756:	learn: 0.0000000	total: 4.25s	remaining: 1.36s
# 757:	learn: 0.0000000	total: 4.26s	remaining: 1.36s
# 758:	learn: 0.0000000	total: 4.26s	remaining: 1.35s
# 759:	learn: 0.0000000	total: 4.27s	remaining: 1.35s
# 760:	learn: 0.0000000	total: 4.27s	remaining: 1.34s
# 761:	learn: 0.0000000	total: 4.28s	remaining: 1.34s
# 762:	learn: 0.0000000	total: 4.28s	remaining: 1.33s
# 763:	learn: 0.0000000	total: 4.29s	remaining: 1.32s
# 764:	learn: 0.0000000	total: 4.29s	remaining: 1.32s
# 765:	learn: 0.0000000	total: 4.3s	remaining: 1.31s
# 766:	learn: 0.0000000	total: 4.3s	remaining: 1.31s
# 767:	learn: 0.0000000	total: 4.31s	remaining: 1.3s
# 768:	learn: 0.0000000	total: 4.32s	remaining: 1.3s
# 769:	learn: 0.0000000	total: 4.32s	remaining: 1.29s
# 770:	learn: 0.0000000	total: 4.33s	remaining: 1.28s
# 771:	learn: 0.0000000	total: 4.33s	remaining: 1.28s
# 772:	learn: 0.0000000	total: 4.34s	remaining: 1.27s
# 773:	learn: 0.0000000	total: 4.35s	remaining: 1.27s
# 774:	learn: 0.0000000	total: 4.35s	remaining: 1.26s
# 775:	learn: 0.0000000	total: 4.36s	remaining: 1.26s
# 776:	learn: 0.0000000	total: 4.36s	remaining: 1.25s
# 777:	learn: 0.0000000	total: 4.37s	remaining: 1.25s
# 778:	learn: 0.0000000	total: 4.38s	remaining: 1.24s
# 779:	learn: 0.0000000	total: 4.38s	remaining: 1.24s
# 780:	learn: 0.0000000	total: 4.39s	remaining: 1.23s
# 781:	learn: 0.0000000	total: 4.39s	remaining: 1.22s
# 782:	learn: 0.0000000	total: 4.4s	remaining: 1.22s
# 783:	learn: 0.0000000	total: 4.4s	remaining: 1.21s
# 784:	learn: 0.0000000	total: 4.41s	remaining: 1.21s
# 785:	learn: 0.0000000	total: 4.41s	remaining: 1.2s
# 786:	learn: 0.0000000	total: 4.42s	remaining: 1.2s
# 787:	learn: 0.0000000	total: 4.42s	remaining: 1.19s
# 788:	learn: 0.0000000	total: 4.43s	remaining: 1.19s
# 789:	learn: 0.0000000	total: 4.44s	remaining: 1.18s
# 790:	learn: 0.0000000	total: 4.44s	remaining: 1.17s
# 791:	learn: 0.0000000	total: 4.45s	remaining: 1.17s
# 792:	learn: 0.0000000	total: 4.45s	remaining: 1.16s
# 793:	learn: 0.0000000	total: 4.46s	remaining: 1.16s
# 794:	learn: 0.0000000	total: 4.46s	remaining: 1.15s
# 795:	learn: 0.0000000	total: 4.47s	remaining: 1.15s
# 796:	learn: 0.0000000	total: 4.47s	remaining: 1.14s
# 797:	learn: 0.0000000	total: 4.48s	remaining: 1.13s
# 798:	learn: 0.0000000	total: 4.48s	remaining: 1.13s
# 799:	learn: 0.0000000	total: 4.49s	remaining: 1.12s
# 800:	learn: 0.0000000	total: 4.49s	remaining: 1.12s
# 801:	learn: 0.0000000	total: 4.5s	remaining: 1.11s
# 802:	learn: 0.0000000	total: 4.51s	remaining: 1.1s
# 803:	learn: 0.0000000	total: 4.51s	remaining: 1.1s
# 804:	learn: 0.0000000	total: 4.52s	remaining: 1.09s
# 805:	learn: 0.0000000	total: 4.53s	remaining: 1.09s
# 806:	learn: 0.0000000	total: 4.53s	remaining: 1.08s
# 807:	learn: 0.0000000	total: 4.54s	remaining: 1.08s
# 808:	learn: 0.0000000	total: 4.55s	remaining: 1.07s
# 809:	learn: 0.0000000	total: 4.55s	remaining: 1.07s
# 810:	learn: 0.0000000	total: 4.56s	remaining: 1.06s
# 811:	learn: 0.0000000	total: 4.56s	remaining: 1.06s
# 812:	learn: 0.0000000	total: 4.57s	remaining: 1.05s
# 813:	learn: 0.0000000	total: 4.57s	remaining: 1.04s
# 814:	learn: 0.0000000	total: 4.58s	remaining: 1.04s
# 815:	learn: 0.0000000	total: 4.58s	remaining: 1.03s
# 816:	learn: 0.0000000	total: 4.59s	remaining: 1.03s
# 817:	learn: 0.0000000	total: 4.59s	remaining: 1.02s
# 818:	learn: 0.0000000	total: 4.6s	remaining: 1.02s
# 819:	learn: 0.0000000	total: 4.61s	remaining: 1.01s
# 820:	learn: 0.0000000	total: 4.61s	remaining: 1s
# 821:	learn: 0.0000000	total: 4.62s	remaining: 1s
# 822:	learn: 0.0000000	total: 4.62s	remaining: 995ms
# 823:	learn: 0.0000000	total: 4.63s	remaining: 989ms
# 824:	learn: 0.0000000	total: 4.63s	remaining: 983ms
# 825:	learn: 0.0000000	total: 4.64s	remaining: 978ms
# 826:	learn: 0.0000000	total: 4.64s	remaining: 972ms
# 827:	learn: 0.0000000	total: 4.65s	remaining: 966ms
# 828:	learn: 0.0000000	total: 4.66s	remaining: 961ms
# 829:	learn: 0.0000000	total: 4.66s	remaining: 955ms
# 830:	learn: 0.0000000	total: 4.67s	remaining: 949ms
# 831:	learn: 0.0000000	total: 4.67s	remaining: 944ms
# 832:	learn: 0.0000000	total: 4.68s	remaining: 938ms
# 833:	learn: 0.0000000	total: 4.69s	remaining: 933ms
# 834:	learn: 0.0000000	total: 4.69s	remaining: 927ms
# 835:	learn: 0.0000000	total: 4.7s	remaining: 922ms
# 836:	learn: 0.0000000	total: 4.71s	remaining: 917ms
# 837:	learn: 0.0000000	total: 4.71s	remaining: 911ms
# 838:	learn: 0.0000000	total: 4.72s	remaining: 906ms
# 839:	learn: 0.0000000	total: 4.73s	remaining: 900ms
# 840:	learn: 0.0000000	total: 4.73s	remaining: 895ms
# 841:	learn: 0.0000000	total: 4.74s	remaining: 890ms
# 842:	learn: 0.0000000	total: 4.75s	remaining: 884ms
# 843:	learn: 0.0000000	total: 4.75s	remaining: 878ms
# 844:	learn: 0.0000000	total: 4.76s	remaining: 873ms
# 845:	learn: 0.0000000	total: 4.76s	remaining: 867ms
# 846:	learn: 0.0000000	total: 4.77s	remaining: 861ms
# 847:	learn: 0.0000000	total: 4.77s	remaining: 856ms
# 848:	learn: 0.0000000	total: 4.78s	remaining: 850ms
# 849:	learn: 0.0000000	total: 4.79s	remaining: 844ms
# 850:	learn: 0.0000000	total: 4.79s	remaining: 839ms
# 851:	learn: 0.0000000	total: 4.8s	remaining: 834ms
# 852:	learn: 0.0000000	total: 4.81s	remaining: 828ms
# 853:	learn: 0.0000000	total: 4.82s	remaining: 823ms
# 854:	learn: 0.0000000	total: 4.82s	remaining: 818ms
# 855:	learn: 0.0000000	total: 4.83s	remaining: 813ms
# 856:	learn: 0.0000000	total: 4.84s	remaining: 807ms
# 857:	learn: 0.0000000	total: 4.84s	remaining: 801ms
# 858:	learn: 0.0000000	total: 4.85s	remaining: 796ms
# 859:	learn: 0.0000000	total: 4.85s	remaining: 790ms
# 860:	learn: 0.0000000	total: 4.86s	remaining: 784ms
# 861:	learn: 0.0000000	total: 4.86s	remaining: 778ms
# 862:	learn: 0.0000000	total: 4.87s	remaining: 772ms
# 863:	learn: 0.0000000	total: 4.87s	remaining: 767ms
# 864:	learn: 0.0000000	total: 4.88s	remaining: 761ms
# 865:	learn: 0.0000000	total: 4.88s	remaining: 755ms
# 866:	learn: 0.0000000	total: 4.89s	remaining: 750ms
# 867:	learn: 0.0000000	total: 4.89s	remaining: 744ms
# 868:	learn: 0.0000000	total: 4.9s	remaining: 738ms
# 869:	learn: 0.0000000	total: 4.91s	remaining: 733ms
# 870:	learn: 0.0000000	total: 4.91s	remaining: 728ms
# 871:	learn: 0.0000000	total: 4.92s	remaining: 722ms
# 872:	learn: 0.0000000	total: 4.92s	remaining: 716ms
# 873:	learn: 0.0000000	total: 4.93s	remaining: 711ms
# 874:	learn: 0.0000000	total: 4.93s	remaining: 705ms
# 875:	learn: 0.0000000	total: 4.94s	remaining: 699ms
# 876:	learn: 0.0000000	total: 4.95s	remaining: 694ms
# 877:	learn: 0.0000000	total: 4.95s	remaining: 688ms
# 878:	learn: 0.0000000	total: 4.96s	remaining: 682ms
# 879:	learn: 0.0000000	total: 4.96s	remaining: 677ms
# 880:	learn: 0.0000000	total: 4.97s	remaining: 671ms
# 881:	learn: 0.0000000	total: 4.97s	remaining: 665ms
# 882:	learn: 0.0000000	total: 4.98s	remaining: 660ms
# 883:	learn: 0.0000000	total: 4.98s	remaining: 654ms
# 884:	learn: 0.0000000	total: 4.99s	remaining: 649ms
# 885:	learn: 0.0000000	total: 5s	remaining: 643ms
# 886:	learn: 0.0000000	total: 5s	remaining: 638ms
# 887:	learn: 0.0000000	total: 5.01s	remaining: 632ms
# 888:	learn: 0.0000000	total: 5.02s	remaining: 626ms
# 889:	learn: 0.0000000	total: 5.02s	remaining: 621ms
# 890:	learn: 0.0000000	total: 5.03s	remaining: 615ms
# 891:	learn: 0.0000000	total: 5.03s	remaining: 609ms
# 892:	learn: 0.0000000	total: 5.04s	remaining: 604ms
# 893:	learn: 0.0000000	total: 5.04s	remaining: 598ms
# 894:	learn: 0.0000000	total: 5.05s	remaining: 592ms
# 895:	learn: 0.0000000	total: 5.05s	remaining: 587ms
# 896:	learn: 0.0000000	total: 5.06s	remaining: 581ms
# 897:	learn: 0.0000000	total: 5.07s	remaining: 575ms
# 898:	learn: 0.0000000	total: 5.07s	remaining: 570ms
# 899:	learn: 0.0000000	total: 5.08s	remaining: 564ms
# 900:	learn: 0.0000000	total: 5.08s	remaining: 559ms
# 901:	learn: 0.0000000	total: 5.09s	remaining: 553ms
# 902:	learn: 0.0000000	total: 5.09s	remaining: 547ms
# 903:	learn: 0.0000000	total: 5.1s	remaining: 542ms
# 904:	learn: 0.0000000	total: 5.11s	remaining: 536ms
# 905:	learn: 0.0000000	total: 5.11s	remaining: 530ms
# 906:	learn: 0.0000000	total: 5.12s	remaining: 525ms
# 907:	learn: 0.0000000	total: 5.12s	remaining: 519ms
# 908:	learn: 0.0000000	total: 5.13s	remaining: 513ms
# 909:	learn: 0.0000000	total: 5.13s	remaining: 508ms
# 910:	learn: 0.0000000	total: 5.14s	remaining: 502ms
# 911:	learn: 0.0000000	total: 5.15s	remaining: 497ms
# 912:	learn: 0.0000000	total: 5.15s	remaining: 491ms
# 913:	learn: 0.0000000	total: 5.16s	remaining: 485ms
# 914:	learn: 0.0000000	total: 5.16s	remaining: 480ms
# 915:	learn: 0.0000000	total: 5.17s	remaining: 474ms
# 916:	learn: 0.0000000	total: 5.18s	remaining: 469ms
# 917:	learn: 0.0000000	total: 5.18s	remaining: 463ms
# 918:	learn: 0.0000000	total: 5.19s	remaining: 457ms
# 919:	learn: 0.0000000	total: 5.19s	remaining: 452ms
# 920:	learn: 0.0000000	total: 5.2s	remaining: 446ms
# 921:	learn: 0.0000000	total: 5.2s	remaining: 440ms
# 922:	learn: 0.0000000	total: 5.21s	remaining: 435ms
# 923:	learn: 0.0000000	total: 5.21s	remaining: 429ms
# 924:	learn: 0.0000000	total: 5.22s	remaining: 423ms
# 925:	learn: 0.0000000	total: 5.22s	remaining: 418ms
# 926:	learn: 0.0000000	total: 5.23s	remaining: 412ms
# 927:	learn: 0.0000000	total: 5.24s	remaining: 406ms
# 928:	learn: 0.0000000	total: 5.25s	remaining: 401ms
# 929:	learn: 0.0000000	total: 5.25s	remaining: 396ms
# 930:	learn: 0.0000000	total: 5.26s	remaining: 390ms
# 931:	learn: 0.0000000	total: 5.27s	remaining: 385ms
# 932:	learn: 0.0000000	total: 5.28s	remaining: 379ms
# 933:	learn: 0.0000000	total: 5.29s	remaining: 374ms
# 934:	learn: 0.0000000	total: 5.3s	remaining: 368ms
# 935:	learn: 0.0000000	total: 5.31s	remaining: 363ms
# 936:	learn: 0.0000000	total: 5.32s	remaining: 357ms
# 937:	learn: 0.0000000	total: 5.32s	remaining: 352ms
# 938:	learn: 0.0000000	total: 5.33s	remaining: 346ms
# 939:	learn: 0.0000000	total: 5.34s	remaining: 341ms
# 940:	learn: 0.0000000	total: 5.35s	remaining: 335ms
# 941:	learn: 0.0000000	total: 5.36s	remaining: 330ms
# 942:	learn: 0.0000000	total: 5.36s	remaining: 324ms
# 943:	learn: 0.0000000	total: 5.37s	remaining: 319ms
# 944:	learn: 0.0000000	total: 5.38s	remaining: 313ms
# 945:	learn: 0.0000000	total: 5.38s	remaining: 307ms
# 946:	learn: 0.0000000	total: 5.38s	remaining: 301ms
# 947:	learn: 0.0000000	total: 5.39s	remaining: 296ms
# 948:	learn: 0.0000000	total: 5.4s	remaining: 290ms
# 949:	learn: 0.0000000	total: 5.4s	remaining: 284ms
# 950:	learn: 0.0000000	total: 5.41s	remaining: 279ms
# 951:	learn: 0.0000000	total: 5.41s	remaining: 273ms
# 952:	learn: 0.0000000	total: 5.42s	remaining: 267ms
# 953:	learn: 0.0000000	total: 5.43s	remaining: 262ms
# 954:	learn: 0.0000000	total: 5.43s	remaining: 256ms
# 955:	learn: 0.0000000	total: 5.44s	remaining: 250ms
# 956:	learn: 0.0000000	total: 5.44s	remaining: 245ms
# 957:	learn: 0.0000000	total: 5.45s	remaining: 239ms
# 958:	learn: 0.0000000	total: 5.46s	remaining: 233ms
# 959:	learn: 0.0000000	total: 5.46s	remaining: 228ms
# 960:	learn: 0.0000000	total: 5.47s	remaining: 222ms
# 961:	learn: 0.0000000	total: 5.47s	remaining: 216ms
# 962:	learn: 0.0000000	total: 5.48s	remaining: 210ms
# 963:	learn: 0.0000000	total: 5.48s	remaining: 205ms
# 964:	learn: 0.0000000	total: 5.49s	remaining: 199ms
# 965:	learn: 0.0000000	total: 5.49s	remaining: 193ms
# 966:	learn: 0.0000000	total: 5.5s	remaining: 188ms
# 967:	learn: 0.0000000	total: 5.5s	remaining: 182ms
# 968:	learn: 0.0000000	total: 5.51s	remaining: 176ms
# 969:	learn: 0.0000000	total: 5.51s	remaining: 171ms
# 970:	learn: 0.0000000	total: 5.52s	remaining: 165ms
# 971:	learn: 0.0000000	total: 5.53s	remaining: 159ms
# 972:	learn: 0.0000000	total: 5.53s	remaining: 154ms
# 973:	learn: 0.0000000	total: 5.54s	remaining: 148ms
# 974:	learn: 0.0000000	total: 5.54s	remaining: 142ms
# 975:	learn: 0.0000000	total: 5.55s	remaining: 137ms
# 976:	learn: 0.0000000	total: 5.56s	remaining: 131ms
# 977:	learn: 0.0000000	total: 5.56s	remaining: 125ms
# 978:	learn: 0.0000000	total: 5.57s	remaining: 119ms
# 979:	learn: 0.0000000	total: 5.57s	remaining: 114ms
# 980:	learn: 0.0000000	total: 5.58s	remaining: 108ms
# 981:	learn: 0.0000000	total: 5.58s	remaining: 102ms
# 982:	learn: 0.0000000	total: 5.59s	remaining: 96.7ms
# 983:	learn: 0.0000000	total: 5.59s	remaining: 91ms
# 984:	learn: 0.0000000	total: 5.6s	remaining: 85.3ms
# 985:	learn: 0.0000000	total: 5.61s	remaining: 79.6ms
# 986:	learn: 0.0000000	total: 5.61s	remaining: 73.9ms
# 987:	learn: 0.0000000	total: 5.62s	remaining: 68.2ms
# 988:	learn: 0.0000000	total: 5.62s	remaining: 62.6ms
# 989:	learn: 0.0000000	total: 5.63s	remaining: 56.9ms
# 990:	learn: 0.0000000	total: 5.64s	remaining: 51.2ms
# 991:	learn: 0.0000000	total: 5.64s	remaining: 45.5ms
# 992:	learn: 0.0000000	total: 5.65s	remaining: 39.8ms
# 993:	learn: 0.0000000	total: 5.65s	remaining: 34.1ms
# 994:	learn: 0.0000000	total: 5.66s	remaining: 28.4ms
# 995:	learn: 0.0000000	total: 5.66s	remaining: 22.7ms
# 996:	learn: 0.0000000	total: 5.67s	remaining: 17.1ms
# 997:	learn: 0.0000000	total: 5.67s	remaining: 11.4ms
# 998:	learn: 0.0000000	total: 5.68s	remaining: 5.68ms
# 999:	learn: 0.0000000	total: 5.68s	remaining: 0us
# GridSearchCV(cv=TimeSeriesSplit(gap=0, max_train_size=None, n_splits=5, test_size=None),
#              estimator=<catboost.core.CatBoostRegressor object at 0x7f193ddddc40>,
#              param_grid={'learning_rate': [0.5]},
#              scoring='neg_mean_squared_error', verbose=False)

# %%
# выводим на экран параметры лучшей модели для LinearRegression
print('Лучшая модель и её параметры:\n\n', grid_cbr.best_estimator_)
print (f'Метрика MSE лучшей модели, полученная кросс-валидацией: {grid_cbr.best_score_: .2f}')
print (f'Метрика RMSE лучшей модели, полученная кросс-валидацией: {(grid_cbr.best_score_*-1)**0.5: .2f}')
# Out:
# Лучшая модель и её параметры:
#
#  <catboost.core.CatBoostRegressor object at 0x7f193dcbcfa0>
# Метрика MSE лучшей модели, полученная кросс-валидацией: -2213.03
# Метрика RMSE лучшей модели, полученная кросс-валидацией:  47.04

# %% [markdown]
# **RMSE на кросс-валидации: 47.04**

# %% [markdown]
# Сведем результаты наших изысканий в одну таблицу, чтобы сделать вывод

# %%
display(
    pd.DataFrame([round((grid_lr.best_score_*-1)**0.5,2),
              round((grid_dtr.best_score_*-1)**0.5,2),
              round((grid_cbr.best_score_*-1)**0.5,2)],
              index=['LinearRegression','DecisionTreeRegression','CatBoostRegression'],
              columns=['RMSE']).sort_index(ascending=False)
       )
# Out:
#                          RMSE
# LinearRegression        46.53
# DecisionTreeRegression  47.41
# CatBoostRegression      47.04

# %% [markdown]
# **Вывод:**
# Лучший результат показала **линейная модель** без дополнительных параметров с **rmse = 46.53**

# %% [markdown]
# ## Тестирование LinearRegression

# %%
# рассчитаем предсказания выбранной моделью и сравним с истинными
y_pred = grid_lr.best_estimator_.predict(X_test)

# вычисляем значение rmse
rmse = round(mean_squared_error(y_test, y_pred)**0.5,2)
print(f'RMSE тестовой выборки {rmse}')
# Out:
# RMSE тестовой выборки 41.64

# %% [markdown]
# На тестовой выборке линейная модель показала ошибку, удовлетворяющую условию задания, - менее 48.

# %%
# отобразим тестовые и предсказанные данные на графике
plt.plot(y_test.index, y_test, '-r',
         y_test.index, y_pred, '-b')
ax=plt.gca()
ax.set_title('График соотношения истинных и предсказанных значений')
ax.set_xlabel('Значение')
ax.set_ylabel('Количество')
ax.legend(loc ='upper right')
plt.show()
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# Из графика видим, что предсказания модели чаще заниженные, поэтому водителей по-прежнему может не хватить.
# Посмотрим на важность признаков.

# %%
feature_importance = grid_lr.best_estimator_.coef_
feature_names = X_test.columns

# %%
feat_imp = pd.DataFrame(feature_importance,
                        index = feature_names,
                        columns=['importance'])

# %%
# Отобразим на графике важность признаков
plt.rcParams["figure.figsize"] = (15,8)
ax=feat_imp[:5].sort_values('importance').plot(kind ='barh', color='blue', alpha=0.4)
ax.set_title('Важность признаков')
ax.set_xlabel('Важность')
ax.set_ylabel('Признак')
plt.show()

# %% [markdown]
# Из графика видим, что большой вес (важность) у дня месяца, часа и полей с временной разницей 1 и 2 часа.

# %%
# подсчитаем среднюю ошибку прогноза
print(f'Средняя ошибка прогноза составляет: {round(abs((y_pred-y_test)).mean())} заказ')
# Out:
# Средняя ошибка прогноза составляет: 31 заказ

# %% [markdown]
# **Вывод:** выбранные признаки для построения модели позволили построить модель, которая в среднем ошибается на 31 заказ.

# %% [markdown]
# **Общие выводы:**
# 1. Проведен анализ предоставленных заказчиком  данных о заказх такси в аэропорт.
# 2. Поскольку исходные данные являются временным рядом, то в ходе предобработки и исследования проведен ресемплинг до 1 часа, на который мы и должны сделать прогноз:
#     - дубли отсутствуют,
#     - аномальные значения отсутствуют,
#     - пропуски отсутствуют.
# 3. Создана функция, которая рассчитывает дополнительные признаки для обучения модели: временные сдвиги, день месяца и час.
# 4. Выбраны 3 модели для предсказания количества заказов:
#     - LinearRegression,
#     - DecisionTreeRegressor,
#     - CatBoostRegressor.
# 5. Подобраны гиперпараметры для двух последних выбранных моделей, а линейная регрессия взята без дополнительных настроек.
# 6. В качестве показателя точности построения модели выбрана ошибка RMSE, которая определялась на кросс-валидации для временных рядов.
# 7. По результатам сравнения построенных моделей выбрана модель LinearRegression спуска, чьи прогнозы оказались ближе всех к истинным и ошибка на тестовых данных соответствовала условиям задачи (rmse<=48).
# 8. Проведен анализ важности признаков модели, построен график сравнения предсказаний и истинных значений. Самыми важными признаками оказались:
#     - день месяца,
#     - час,
#     - сдвиг на 1 час,
#     - сдвиг на 2 часа.
# 9. Средняя недооценка количества заказов построенной моделью составляет 31.
